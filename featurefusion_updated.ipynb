# %% [markdown]
# #### final code

# %%
import cv2
import mediapipe as mp
import torch
import torchvision
import numpy as np
import os
import pandas as pd
from torchvision.transforms import functional as F

# Initialize MediaPipe Pose
mp_pose = mp.solutions.pose
mp_drawing = mp.solutions.drawing_utils
SELECTED_LANDMARKS = {
    "LEFT_SHOULDER": mp_pose.PoseLandmark.LEFT_SHOULDER,
    "LEFT_ELBOW": mp_pose.PoseLandmark.LEFT_ELBOW,
    "LEFT_WRIST": mp_pose.PoseLandmark.LEFT_WRIST,
    "LEFT_HIP": mp_pose.PoseLandmark.LEFT_HIP,
    "LEFT_KNEE": mp_pose.PoseLandmark.LEFT_KNEE,
    "LEFT_ANKLE": mp_pose.PoseLandmark.LEFT_ANKLE,
}

# Initialize Keypoint R-CNN
model_rcnn = torchvision.models.detection.keypointrcnn_resnet50_fpn(pretrained=True)
model_rcnn.eval()
device = torch.device("cpu")
model_rcnn.to(device)
COCO_KEYPOINTS = {
    "LEFT_SHOULDER": 5,
    "LEFT_ELBOW": 7,
    "LEFT_WRIST": 9,
    "LEFT_HIP": 11,
    "LEFT_KNEE": 13,
    "LEFT_ANKLE": 15,
}

EDGES = [
    ("LEFT_SHOULDER", "LEFT_ELBOW"),
    ("LEFT_ELBOW", "LEFT_WRIST"),
    ("LEFT_SHOULDER", "LEFT_HIP"),
    ("LEFT_HIP", "LEFT_KNEE"),
    ("LEFT_KNEE", "LEFT_ANKLE"),
]

# Default weights (balanced for most keypoints)
KEYPOINT_WEIGHTS_DEFAULT = {
    "LEFT_SHOULDER": {"mediapipe": 0.4, "rcnn": 0.6},
    "LEFT_ELBOW": {"mediapipe": 0.5, "rcnn": 0.5},
    "LEFT_WRIST": {"mediapipe": 0.3, "rcnn": 0.7},
    "LEFT_HIP": {"mediapipe": 0.4, "rcnn": 0.6},
    "LEFT_KNEE": {"mediapipe": 0.5, "rcnn": 0.5},  # Balanced weights by default
    "LEFT_ANKLE": {"mediapipe": 0.3, "rcnn": 0.7},
}

# Weights for cycling posture (favor R-CNN for knee)
KEYPOINT_WEIGHTS_CYCLING = {
    "LEFT_SHOULDER": {"mediapipe": 0.4, "rcnn": 0.6},
    "LEFT_ELBOW": {"mediapipe": 0.5, "rcnn": 0.5},
    "LEFT_WRIST": {"mediapipe": 0.3, "rcnn": 0.7},
    "LEFT_HIP": {"mediapipe": 0.4, "rcnn": 0.6},
    "LEFT_KNEE": {"mediapipe": 0.3, "rcnn": 0.7},  # Favor R-CNN for knee in cycling
    "LEFT_ANKLE": {"mediapipe": 0.3, "rcnn": 0.7},
}

def get_mediapipe_keypoints(image_path):
    image = cv2.imread(image_path)
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    normalized_keypoints = {}
    
    with mp_pose.Pose(static_image_mode=True, min_detection_confidence=0.5) as pose:
        results = pose.process(image_rgb)
        if results.pose_landmarks:
            height, width, _ = image.shape
            for name, landmark_enum in SELECTED_LANDMARKS.items():
                landmark = results.pose_landmarks.landmark[landmark_enum]
                normalized_keypoints[name] = (landmark.x, landmark.y, landmark.visibility)
    return normalized_keypoints

def get_rcnn_keypoints(image_path):
    image = cv2.imread(image_path)
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image_tensor = F.to_tensor(image_rgb).unsqueeze(0).to(device)
    
    with torch.no_grad():
        outputs = model_rcnn(image_tensor)
    keypoints = outputs[0]["keypoints"].cpu().numpy()
    scores = outputs[0]["scores"].cpu().numpy()
    keypoints = keypoints[scores > 0.5]
    
    if keypoints.shape[0] == 0:
        return {}
    
    height, width = image.shape[:2]
    selected_keypoints = {}
    for name, index in COCO_KEYPOINTS.items():
        x, y, conf = keypoints[0][index]
        x_normalized = x / width
        y_normalized = y / height
        selected_keypoints[name] = (x_normalized, y_normalized, conf)
    return selected_keypoints

def compute_distance(p1, p2):
    return np.sqrt((p1[0] - p2[0])**2 + (p1[1] - p2[1])**2)

def compute_angle(p1, p2, p3):
    v1 = np.array([p1[0] - p2[0], p1[1] - p2[1]])
    v2 = np.array([p3[0] - p2[0], p3[1] - p2[1]])
    cos_angle = np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2) + 1e-6)
    cos_angle = np.clip(cos_angle, -1.0, 1.0)
    return np.degrees(np.arccos(cos_angle))

def is_cycling_pose(keypoints):
    """Determine if the pose is likely a cycling posture."""
    if ("LEFT_SHOULDER" in keypoints and "LEFT_HIP" in keypoints and 
        "LEFT_KNEE" in keypoints and "LEFT_ANKLE" in keypoints):
        shoulder_y = keypoints["LEFT_SHOULDER"][1]
        hip_y = keypoints["LEFT_HIP"][1]
        knee_y = keypoints["LEFT_KNEE"][1]
        ankle_y = keypoints["LEFT_ANKLE"][1]
        shoulder_conf = keypoints["LEFT_SHOULDER"][2]
        hip_conf = keypoints["LEFT_HIP"][2]
        knee_conf = keypoints["LEFT_KNEE"][2]
        ankle_conf = keypoints["LEFT_ANKLE"][2]
        
        if shoulder_conf > 0.6 and hip_conf > 0.6 and knee_conf > 0.6 and ankle_conf > 0.6:
            # Check if torso is leaning forward (shoulder above hip but not too far)
            torso_lean = abs(shoulder_y - hip_y)
            # Check knee position relative to hip and ankle
            knee_angle = compute_angle(
                (keypoints["LEFT_HIP"][0], keypoints["LEFT_HIP"][1]),
                (keypoints["LEFT_KNEE"][0], keypoints["LEFT_KNEE"][1]),
                (keypoints["LEFT_ANKLE"][0], keypoints["LEFT_ANKLE"][1])
            )
            # Cycling posture: torso leaning forward, knee bent (angle typically 30°-150°)
            if torso_lean < 0.3 and 30 < knee_angle < 150:
                return True
    return False

def check_anatomical_violation(key, x, y, keypoints):
    penalty = 0.0
    
    if key == "LEFT_WRIST" and "LEFT_SHOULDER" in keypoints and keypoints["LEFT_SHOULDER"][2] > 0.6:
        shoulder_y = keypoints["LEFT_SHOULDER"][1]
        if y < shoulder_y - 0.05:
            penalty += 0.3
    
    if key == "LEFT_KNEE" and "LEFT_HIP" in keypoints and "LEFT_ANKLE" in keypoints:
        hip_y = keypoints["LEFT_HIP"][1]
        ankle_y = keypoints["LEFT_ANKLE"][1]
        hip_conf = keypoints["LEFT_HIP"][2]
        ankle_conf = keypoints["LEFT_ANKLE"][2]
        
        # Basic constraint: knee should not be above hip (relaxed for cycling)
        if y < hip_y - 0.05 and hip_conf > 0.6:
            penalty += 0.2  # Reduced penalty to allow for bent poses
        
        # Soft angle constraint: penalize extreme angles but don't enforce strictly
        if hip_conf > 0.6 and ankle_conf > 0.6:
            hip_x, hip_y, _ = keypoints["LEFT_HIP"]
            ankle_x, ankle_y, _ = keypoints["LEFT_ANKLE"]
            angle = compute_angle((hip_x, hip_y), (x, y), (ankle_x, ankle_y))
            if angle < 20 or angle > 170:  # Very extreme angles are unlikely
                penalty += 0.2
                print(f"Knee angle warning: {angle:.2f} degrees (extreme angle detected).")
    
    if key == "LEFT_ANKLE" and "LEFT_KNEE" in keypoints and keypoints["LEFT_KNEE"][2] > 0.6:
        knee_y = keypoints["LEFT_KNEE"][1]
        if y < knee_y - 0.05:
            penalty += 0.3
    
    if key == "LEFT_SHOULDER" and "LEFT_HIP" in keypoints and keypoints["LEFT_HIP"][2] > 0.6:
        hip_y = keypoints["LEFT_HIP"][1]
        if y > hip_y + 0.05:
            penalty += 0.3
    
    return penalty

def evaluate_keypoint_consistency(key, keypoints, other_keypoints, edges):
    x, y, conf = keypoints[key]
    if conf <= 0.5:  # Stricter threshold for consistency evaluation
        return 0.0
    
    neighbors = []
    for k1, k2 in edges:
        if k1 == key and k2 in keypoints and keypoints[k2][2] > 0.5:
            neighbors.append(k2)
        elif k2 == key and k1 in keypoints and keypoints[k1][2] > 0.5:
            neighbors.append(k1)
    
    if not neighbors:
        return conf * (1.0 - check_anatomical_violation(key, x, y, keypoints))
    
    consistency_score = 0.0
    count = 0
    for neighbor in neighbors:
        if neighbor in other_keypoints and other_keypoints[neighbor][2] > 0.5:
            my_x, my_y, _ = keypoints[key]
            my_neighbor_x, my_neighbor_y, _ = keypoints[neighbor]
            other_x, other_y, _ = other_keypoints[key]
            other_neighbor_x, other_neighbor_y, _ = other_keypoints[neighbor]
            
            my_dx = my_x - my_neighbor_x
            my_dy = my_y - my_neighbor_y
            other_dx = other_x - other_neighbor_x
            other_dy = other_y - other_neighbor_y
            
            my_dist = compute_distance((my_x, my_y), (my_neighbor_x, my_neighbor_y)) + 1e-6
            other_dist = compute_distance((other_x, other_y), (other_neighbor_x, other_neighbor_y)) + 1e-6
            my_dx_norm = my_dx / my_dist
            my_dy_norm = my_dy / my_dist
            other_dx_norm = other_dx / other_dist
            other_dy_norm = other_dy / other_dist
            
            similarity = 1.0 - 0.5 * (abs(my_dx_norm - other_dx_norm) + abs(my_dy_norm - other_dy_norm))
            consistency_score += similarity
            count += 1
    
    if count > 0:
        consistency_score /= count
        anatomical_penalty = check_anatomical_violation(key, x, y, keypoints)
        consistency_score *= (1.0 - anatomical_penalty)
        return 0.3 * consistency_score + 0.7 * conf
    return conf * (1.0 - check_anatomical_violation(key, x, y, keypoints))

def fuse_keypoints_selective(mediapipe_kps, rcnn_kps, edges):
    # Determine if the pose is cycling-like (based on MediaPipe keypoints for simplicity)
    is_cycling = is_cycling_pose(mediapipe_kps)
    KEYPOINT_WEIGHTS = KEYPOINT_WEIGHTS_CYCLING if is_cycling else KEYPOINT_WEIGHTS_DEFAULT
    print(f"Pose classified as {'cycling' if is_cycling else 'non-cycling'}. Using weights: {KEYPOINT_WEIGHTS}")
    
    fused_keypoints = {}
    
    for key in SELECTED_LANDMARKS.keys():
        mp_kp = mediapipe_kps.get(key, (0.0, 0.0, 0.0))
        rcnn_kp = rcnn_kps.get(key, (0.0, 0.0, 0.0))
        
        mp_x, mp_y, mp_conf = mp_kp
        rcnn_x, rcnn_y, rcnn_conf = rcnn_kp
        
        mp_consistency = evaluate_keypoint_consistency(key, mediapipe_kps, rcnn_kps, edges) if mp_conf > 0 else 0.0
        rcnn_consistency = evaluate_keypoint_consistency(key, rcnn_kps, mediapipe_kps, edges) if rcnn_conf > 0 else 0.0
        
        print(f"{key} - MediaPipe Consistency: {mp_consistency:.2f}, R-CNN Consistency: {rcnn_consistency:.2f}")
        
        mp_weight = KEYPOINT_WEIGHTS[key]["mediapipe"]
        rcnn_weight = KEYPOINT_WEIGHTS[key]["rcnn"]
        mp_adjusted = mp_consistency * mp_weight
        rcnn_adjusted = rcnn_consistency * rcnn_weight
        
        if mp_adjusted > rcnn_adjusted + 0.1:
            fused_x, fused_y, fused_conf = mp_x, mp_y, mp_conf
            print(f"{key}: Using MediaPipe prediction.")
        elif rcnn_adjusted > mp_adjusted + 0.1:
            fused_x, fused_y, fused_conf = rcnn_x, rcnn_y, rcnn_conf
            print(f"{key}: Using R-CNN prediction.")
        elif mp_conf > 0 and rcnn_conf > 0:
            total_weight = mp_weight + rcnn_weight
            mp_fusion_weight = mp_weight / total_weight
            rcnn_fusion_weight = rcnn_weight / total_weight
            fused_x = mp_fusion_weight * mp_x + rcnn_fusion_weight * rcnn_x
            fused_y = mp_fusion_weight * mp_y + rcnn_fusion_weight * rcnn_y
            fused_conf = max(mp_conf, rcnn_conf)
            print(f"{key}: Using weighted averaging with weights (MP: {mp_fusion_weight:.2f}, R-CNN: {rcnn_fusion_weight:.2f}).")
        elif mp_conf > 0:
            fused_x, fused_y, fused_conf = mp_x, mp_y, mp_conf
            print(f"{key}: Using MediaPipe prediction (R-CNN unavailable).")
        elif rcnn_conf > 0:
            fused_x, fused_y, fused_conf = rcnn_x, rcnn_y, rcnn_conf
            print(f"{key}: Using R-CNN prediction (MediaPipe unavailable).")
        else:
            fused_x, fused_y, fused_conf = 0.0, 0.0, 0.0
            print(f"{key}: No reliable prediction available.")
        
        fused_keypoints[key] = (fused_x, fused_y, fused_conf)
    
    return fused_keypoints

def fallback_and_correct(fused_kps, mediapipe_kps, rcnn_kps, edges):
    adjusted_kps = fused_kps.copy()
    
    # Fallback for low-confidence keypoints
    for key in adjusted_kps.keys():
        x, y, conf = adjusted_kps[key]
        if conf <= 0.5:  # Stricter threshold for fallback
            neighbors = []
            for k1, k2 in edges:
                if k1 == key and k2 in adjusted_kps and adjusted_kps[k2][2] > 0.5:
                    neighbors.append((k2, adjusted_kps[k2]))
                elif k2 == key and k1 in adjusted_kps and adjusted_kps[k1][2] > 0.5:
                    neighbors.append((k1, adjusted_kps[k1]))
            
            if neighbors:
                total_conf = sum(n_conf for _, (_, _, n_conf) in neighbors)
                if total_conf > 0:
                    avg_x = sum(nx * n_conf for _, (nx, _, n_conf) in neighbors) / total_conf
                    avg_y = sum(ny * n_conf for _, (_, ny, n_conf) in neighbors) / total_conf
                    adjusted_kps[key] = (avg_x, avg_y, 0.5)
                    print(f"{key}: Estimated position using neighbors.")
    
    # Softer anatomical corrections
    if "LEFT_SHOULDER" in adjusted_kps and "LEFT_HIP" in adjusted_kps:
        shoulder_y = adjusted_kps["LEFT_SHOULDER"][1]
        hip_y = adjusted_kps["LEFT_HIP"][1]
        shoulder_conf = adjusted_kps["LEFT_SHOULDER"][2]
        hip_conf = adjusted_kps["LEFT_HIP"][2]
        if shoulder_y > hip_y + 0.05 and shoulder_conf > 0.6 and hip_conf > 0.6:
            adjusted_kps["LEFT_SHOULDER"] = (adjusted_kps["LEFT_SHOULDER"][0], hip_y - 0.05, shoulder_conf * 0.9)
            print("Corrected LEFT_SHOULDER position (was below hip).")
    
    if "LEFT_SHOULDER" in adjusted_kps and "LEFT_WRIST" in adjusted_kps:
        shoulder_y = adjusted_kps["LEFT_SHOULDER"][1]
        wrist_y = adjusted_kps["LEFT_WRIST"][1]
        wrist_conf = adjusted_kps["LEFT_WRIST"][2]
        if wrist_y < shoulder_y - 0.05 and wrist_conf > 0.6:
            adjusted_kps["LEFT_WRIST"] = (adjusted_kps["LEFT_WRIST"][0], shoulder_y, wrist_conf * 0.8)
            print("Corrected LEFT_WRIST position (was above shoulder).")
    
    if "LEFT_HIP" in adjusted_kps and "LEFT_KNEE" in adjusted_kps:
        hip_y = adjusted_kps["LEFT_HIP"][1]
        knee_y = adjusted_kps["LEFT_KNEE"][1]
        knee_conf = adjusted_kps["LEFT_KNEE"][2]
        if knee_y < hip_y - 0.05 and knee_conf > 0.6:
            # Blend the original position with the corrected position
            corrected_y = hip_y - 0.02
            blended_y = 0.7 * knee_y + 0.3 * corrected_y  # Soft correction
            adjusted_kps["LEFT_KNEE"] = (adjusted_kps["LEFT_KNEE"][0], blended_y, knee_conf * 0.9)
            print("Soft-corrected LEFT_KNEE position (was too far above hip).")
    
    if "LEFT_KNEE" in adjusted_kps and "LEFT_ANKLE" in adjusted_kps:
        knee_y = adjusted_kps["LEFT_KNEE"][1]
        ankle_y = adjusted_kps["LEFT_ANKLE"][1]
        ankle_conf = adjusted_kps["LEFT_ANKLE"][2]
        if ankle_y < knee_y - 0.05 and ankle_conf > 0.6:
            corrected_y = knee_y + 0.02
            blended_y = 0.7 * ankle_y + 0.3 * corrected_y
            adjusted_kps["LEFT_ANKLE"] = (adjusted_kps["LEFT_ANKLE"][0], blended_y, ankle_conf * 0.8)
            print("Soft-corrected LEFT_ANKLE position (was too far above knee).")
    
    return adjusted_kps

def draw_fused_keypoints(image, keypoints):
    height, width = image.shape[:2]
    for name, (x_norm, y_norm, conf) in keypoints.items():
        if conf > 0.5:  # Relaxed threshold for visualization
            x_pixel, y_pixel = int(x_norm * width), int(y_norm * height)
            cv2.circle(image, (x_pixel, y_pixel), 5, (255, 0, 0), -1)
            coord_text = f"{name}: ({x_norm:.5f}, {y_norm:.5f})"
            cv2.putText(image, coord_text, (x_pixel + 10, y_pixel - 10), 
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 1)
    return image

def process_dataset(input_folder, output_folder, excel_path):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    data = []
    image_files = [f for f in os.listdir(input_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]
    
    for image_file in image_files:
        print(f"\nProcessing {image_file}...")
        image_path = os.path.join(input_folder, image_file)
        
        try:
            image_no = int(os.path.splitext(image_file)[0])
        except ValueError:
            print(f"Could not extract image number from {image_file}, skipping...")
            continue
        
        image = cv2.imread(image_path)
        if image is None:
            print(f"Failed to load image: {image_path}")
            continue
        
        mediapipe_kps = get_mediapipe_keypoints(image_path)
        rcnn_kps = get_rcnn_keypoints(image_path)
        
        print("\nMediaPipe Keypoints:")
        for name, (x, y, conf) in mediapipe_kps.items():
            print(f"{name}: (x={x:.5f}, y={y:.5f}, confidence={conf:.2f})")
        print("\nR-CNN Keypoints:")
        for name, (x, y, conf) in rcnn_kps.items():
            print(f"{name}: (x={x:.5f}, y={y:.5f}, confidence={conf:.2f})")
        
        fused_keypoints = fuse_keypoints_selective(mediapipe_kps, rcnn_kps, EDGES)
        fused_keypoints = fallback_and_correct(fused_keypoints, mediapipe_kps, rcnn_kps, EDGES)
        
        print("\nFused Keypoints:")
        for name, (x, y, conf) in fused_keypoints.items():
            print(f"{name}: (x={x:.5f}, y={y:.5f}, confidence={conf:.2f})")
        
        row = {
            "image_no": image_no,
            "left_shoulder_x": round(fused_keypoints["LEFT_SHOULDER"][0], 5),
            "left_shoulder_y": round(fused_keypoints["LEFT_SHOULDER"][1], 5),
            "left_elbow_x": round(fused_keypoints["LEFT_ELBOW"][0], 5),
            "left_elbow_y": round(fused_keypoints["LEFT_ELBOW"][1], 5),
            "left_wrist_x": round(fused_keypoints["LEFT_WRIST"][0], 5),
            "left_wrist_y": round(fused_keypoints["LEFT_WRIST"][1], 5),
            "left_hip_x": round(fused_keypoints["LEFT_HIP"][0], 5),
            "left_hip_y": round(fused_keypoints["LEFT_HIP"][1], 5),
            "left_knee_x": round(fused_keypoints["LEFT_KNEE"][0], 5),
            "left_knee_y": round(fused_keypoints["LEFT_KNEE"][1], 5),
            "left_ankle_x": round(fused_keypoints["LEFT_ANKLE"][0], 5),
            "left_ankle_y": round(fused_keypoints["LEFT_ANKLE"][1], 5),
        }
        data.append(row)
        
        output_image = draw_fused_keypoints(image.copy(), fused_keypoints)
        output_path = os.path.join(output_folder, image_file)
        cv2.imwrite(output_path, output_image)
        print(f"Saved annotated image to {output_path}")
    
    df = pd.DataFrame(data)
    df = df.sort_values(by="image_no")
    df.to_excel(excel_path, index=False)
    print(f"Saved keypoint coordinates to {excel_path}")

# Define input and output folders, and Excel file path
input_folder = r"C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\checkdataset"
output_folder = r"C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\checkdataset_final_output_grok3"
excel_path = r"C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\checkdataset_keypoint_coordinates_.xlsx"

# Process the dataset and generate Excel file
process_dataset(input_folder, output_folder, excel_path)
# Out:
# Processing 1.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.47125, y=0.27856, confidence=1.00)
# LEFT_ELBOW: (x=0.46738, y=0.38139, confidence=0.96)
# LEFT_WRIST: (x=0.41266, y=0.36985, confidence=0.98)
# LEFT_HIP: (x=0.56324, y=0.37135, confidence=1.00)
# LEFT_KNEE: (x=0.48337, y=0.43926, confidence=0.98)
# LEFT_ANKLE: (x=0.54677, y=0.54341, confidence=0.95)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.47109, y=0.27152, confidence=1.00)
# LEFT_ELBOW: (x=0.46510, y=0.38354, confidence=1.00)
# LEFT_WRIST: (x=0.41121, y=0.36487, confidence=1.00)
# LEFT_HIP: (x=0.56167, y=0.36487, confidence=1.00)
# LEFT_KNEE: (x=0.48307, y=0.43688, confidence=1.00)
# LEFT_ANKLE: (x=0.54819, y=0.54357, confidence=1.00)
# Pose classified as cycling. Using weights: {'LEFT_SHOULDER': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_ELBOW': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_WRIST': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_HIP': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_KNEE': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_ANKLE': {'mediapipe': 0.3, 'rcnn': 0.7}}
# LEFT_SHOULDER - MediaPipe Consistency: 1.00, R-CNN Consistency: 1.00
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.96, R-CNN Consistency: 0.99
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.96, R-CNN Consistency: 0.98
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_HIP: Using R-CNN prediction.
# LEFT_KNEE - MediaPipe Consistency: 0.98, R-CNN Consistency: 1.00
# LEFT_KNEE: Using R-CNN prediction.
# LEFT_ANKLE - MediaPipe Consistency: 0.96, R-CNN Consistency: 1.00
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.47109, y=0.27152, confidence=1.00)
# LEFT_ELBOW: (x=0.46624, y=0.38247, confidence=1.00)
# LEFT_WRIST: (x=0.41121, y=0.36487, confidence=1.00)
# LEFT_HIP: (x=0.56167, y=0.36487, confidence=1.00)
# LEFT_KNEE: (x=0.48307, y=0.43688, confidence=1.00)
# LEFT_ANKLE: (x=0.54819, y=0.54357, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\checkdataset_final_output_grok3\1.png
#
# Processing 10.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.52190, y=0.25720, confidence=1.00)
# LEFT_ELBOW: (x=0.48761, y=0.33519, confidence=0.99)
# LEFT_WRIST: (x=0.44323, y=0.38391, confidence=0.98)
# LEFT_HIP: (x=0.56888, y=0.41095, confidence=1.00)
# LEFT_KNEE: (x=0.53195, y=0.53234, confidence=0.98)
# LEFT_ANKLE: (x=0.57963, y=0.64543, confidence=0.98)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.52950, y=0.25055, confidence=1.00)
# LEFT_ELBOW: (x=0.49066, y=0.33056, confidence=1.00)
# LEFT_WRIST: (x=0.44209, y=0.38524, confidence=1.00)
# LEFT_HIP: (x=0.57134, y=0.39590, confidence=1.00)
# LEFT_KNEE: (x=0.50186, y=0.46924, confidence=1.00)
# LEFT_ANKLE: (x=0.57806, y=0.64926, confidence=1.00)
# Pose classified as cycling. Using weights: {'LEFT_SHOULDER': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_ELBOW': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_WRIST': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_HIP': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_KNEE': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_ANKLE': {'mediapipe': 0.3, 'rcnn': 0.7}}
# LEFT_SHOULDER - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.98, R-CNN Consistency: 1.00
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 0.95, R-CNN Consistency: 0.95
# LEFT_HIP: Using R-CNN prediction.
# LEFT_KNEE - MediaPipe Consistency: 0.94, R-CNN Consistency: 0.95
# LEFT_KNEE: Using R-CNN prediction.
# LEFT_ANKLE - MediaPipe Consistency: 0.99, R-CNN Consistency: 1.00
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.52950, y=0.25055, confidence=1.00)
# LEFT_ELBOW: (x=0.48913, y=0.33287, confidence=1.00)
# LEFT_WRIST: (x=0.44209, y=0.38524, confidence=1.00)
# LEFT_HIP: (x=0.57134, y=0.39590, confidence=1.00)
# LEFT_KNEE: (x=0.50186, y=0.46924, confidence=1.00)
# LEFT_ANKLE: (x=0.57806, y=0.64926, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\checkdataset_final_output_grok3\10.png
#
# Processing 11.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.48521, y=0.28955, confidence=1.00)
# LEFT_ELBOW: (x=0.46144, y=0.39149, confidence=0.97)
# LEFT_WRIST: (x=0.41090, y=0.37203, confidence=0.97)
# LEFT_HIP: (x=0.55694, y=0.39082, confidence=1.00)
# LEFT_KNEE: (x=0.47237, y=0.44428, confidence=0.95)
# LEFT_ANKLE: (x=0.54395, y=0.52193, confidence=0.93)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.48417, y=0.28171, confidence=1.00)
# LEFT_ELBOW: (x=0.46167, y=0.39368, confidence=1.00)
# LEFT_WRIST: (x=0.40543, y=0.36302, confidence=1.00)
# LEFT_HIP: (x=0.55467, y=0.37635, confidence=1.00)
# LEFT_KNEE: (x=0.47667, y=0.44833, confidence=1.00)
# LEFT_ANKLE: (x=0.55317, y=0.52164, confidence=1.00)
# Pose classified as cycling. Using weights: {'LEFT_SHOULDER': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_ELBOW': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_WRIST': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_HIP': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_KNEE': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_ANKLE': {'mediapipe': 0.3, 'rcnn': 0.7}}
# LEFT_SHOULDER - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.96, R-CNN Consistency: 0.98
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.95, R-CNN Consistency: 0.97
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 0.98, R-CNN Consistency: 0.98
# LEFT_HIP: Using R-CNN prediction.
# LEFT_KNEE - MediaPipe Consistency: 0.94, R-CNN Consistency: 0.97
# LEFT_KNEE: Using R-CNN prediction.
# LEFT_ANKLE - MediaPipe Consistency: 0.94, R-CNN Consistency: 0.99
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.48417, y=0.28171, confidence=1.00)
# LEFT_ELBOW: (x=0.46156, y=0.39258, confidence=1.00)
# LEFT_WRIST: (x=0.40543, y=0.36302, confidence=1.00)
# LEFT_HIP: (x=0.55467, y=0.37635, confidence=1.00)
# LEFT_KNEE: (x=0.47667, y=0.44833, confidence=1.00)
# LEFT_ANKLE: (x=0.55317, y=0.52164, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\checkdataset_final_output_grok3\11.png
#
# Processing 12.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.48434, y=0.30522, confidence=1.00)
# LEFT_ELBOW: (x=0.48234, y=0.41334, confidence=0.96)
# LEFT_WRIST: (x=0.42896, y=0.42127, confidence=0.98)
# LEFT_HIP: (x=0.55842, y=0.38478, confidence=1.00)
# LEFT_KNEE: (x=0.48626, y=0.47124, confidence=0.93)
# LEFT_ANKLE: (x=0.50860, y=0.61852, confidence=0.91)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.48465, y=0.29716, confidence=1.00)
# LEFT_ELBOW: (x=0.48017, y=0.41185, confidence=1.00)
# LEFT_WRIST: (x=0.42558, y=0.41852, confidence=1.00)
# LEFT_HIP: (x=0.56092, y=0.37318, confidence=1.00)
# LEFT_KNEE: (x=0.48390, y=0.46120, confidence=1.00)
# LEFT_ANKLE: (x=0.51306, y=0.62924, confidence=1.00)
# Pose classified as cycling. Using weights: {'LEFT_SHOULDER': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_ELBOW': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_WRIST': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_HIP': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_KNEE': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_ANKLE': {'mediapipe': 0.3, 'rcnn': 0.7}}
# LEFT_SHOULDER - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.97, R-CNN Consistency: 1.00
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.98, R-CNN Consistency: 1.00
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_HIP: Using R-CNN prediction.
# LEFT_KNEE - MediaPipe Consistency: 0.95, R-CNN Consistency: 1.00
# LEFT_KNEE: Using R-CNN prediction.
# LEFT_ANKLE - MediaPipe Consistency: 0.93, R-CNN Consistency: 1.00
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.48465, y=0.29716, confidence=1.00)
# LEFT_ELBOW: (x=0.48125, y=0.41260, confidence=1.00)
# LEFT_WRIST: (x=0.42558, y=0.41852, confidence=1.00)
# LEFT_HIP: (x=0.56092, y=0.37318, confidence=1.00)
# LEFT_KNEE: (x=0.48390, y=0.46120, confidence=1.00)
# LEFT_ANKLE: (x=0.51306, y=0.62924, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\checkdataset_final_output_grok3\12.png
#
# Processing 13.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.45378, y=0.19320, confidence=1.00)
# LEFT_ELBOW: (x=0.47007, y=0.28570, confidence=0.99)
# LEFT_WRIST: (x=0.43832, y=0.36653, confidence=0.99)
# LEFT_HIP: (x=0.51447, y=0.35030, confidence=1.00)
# LEFT_KNEE: (x=0.48855, y=0.49416, confidence=0.92)
# LEFT_ANKLE: (x=0.51410, y=0.65411, confidence=0.93)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.45856, y=0.18608, confidence=1.00)
# LEFT_ELBOW: (x=0.46828, y=0.29005, confidence=1.00)
# LEFT_WRIST: (x=0.43762, y=0.37402, confidence=1.00)
# LEFT_HIP: (x=0.51465, y=0.34203, confidence=1.00)
# LEFT_KNEE: (x=0.49371, y=0.49532, confidence=1.00)
# LEFT_ANKLE: (x=0.51390, y=0.66326, confidence=1.00)
# Pose classified as non-cycling. Using weights: {'LEFT_SHOULDER': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_ELBOW': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_WRIST': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_HIP': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_KNEE': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_ANKLE': {'mediapipe': 0.3, 'rcnn': 0.7}}
# LEFT_SHOULDER - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.99, R-CNN Consistency: 1.00
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_HIP: Using R-CNN prediction.
# LEFT_KNEE - MediaPipe Consistency: 0.93, R-CNN Consistency: 0.99
# LEFT_KNEE: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_ANKLE - MediaPipe Consistency: 0.95, R-CNN Consistency: 0.99
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.45856, y=0.18608, confidence=1.00)
# LEFT_ELBOW: (x=0.46918, y=0.28787, confidence=1.00)
# LEFT_WRIST: (x=0.43762, y=0.37402, confidence=1.00)
# LEFT_HIP: (x=0.51465, y=0.34203, confidence=1.00)
# LEFT_KNEE: (x=0.49113, y=0.49474, confidence=1.00)
# LEFT_ANKLE: (x=0.51390, y=0.66326, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\checkdataset_final_output_grok3\13.png
#
# Processing 14.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.51929, y=0.22500, confidence=1.00)
# LEFT_ELBOW: (x=0.48160, y=0.31614, confidence=1.00)
# LEFT_WRIST: (x=0.43651, y=0.36847, confidence=0.99)
# LEFT_HIP: (x=0.56220, y=0.38765, confidence=1.00)
# LEFT_KNEE: (x=0.50992, y=0.51796, confidence=0.99)
# LEFT_ANKLE: (x=0.53489, y=0.67040, confidence=1.00)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.52456, y=0.21643, confidence=1.00)
# LEFT_ELBOW: (x=0.48491, y=0.31242, confidence=1.00)
# LEFT_WRIST: (x=0.44002, y=0.37108, confidence=1.00)
# LEFT_HIP: (x=0.56047, y=0.38041, confidence=1.00)
# LEFT_KNEE: (x=0.51034, y=0.51373, confidence=1.00)
# LEFT_ANKLE: (x=0.53727, y=0.67771, confidence=1.00)
# Pose classified as cycling. Using weights: {'LEFT_SHOULDER': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_ELBOW': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_WRIST': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_HIP': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_KNEE': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_ANKLE': {'mediapipe': 0.3, 'rcnn': 0.7}}
# LEFT_SHOULDER - MediaPipe Consistency: 1.00, R-CNN Consistency: 1.00
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.98, R-CNN Consistency: 0.99
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_HIP: Using R-CNN prediction.
# LEFT_KNEE - MediaPipe Consistency: 0.99, R-CNN Consistency: 1.00
# LEFT_KNEE: Using R-CNN prediction.
# LEFT_ANKLE - MediaPipe Consistency: 1.00, R-CNN Consistency: 1.00
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.52456, y=0.21643, confidence=1.00)
# LEFT_ELBOW: (x=0.48325, y=0.31428, confidence=1.00)
# LEFT_WRIST: (x=0.44002, y=0.37108, confidence=1.00)
# LEFT_HIP: (x=0.56047, y=0.38041, confidence=1.00)
# LEFT_KNEE: (x=0.51034, y=0.51373, confidence=1.00)
# LEFT_ANKLE: (x=0.53727, y=0.67771, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\checkdataset_final_output_grok3\14.png
#
# Processing 15.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.43735, y=0.28732, confidence=1.00)
# LEFT_ELBOW: (x=0.47308, y=0.35788, confidence=0.98)
# LEFT_WRIST: (x=0.42926, y=0.41533, confidence=0.98)
# LEFT_HIP: (x=0.52203, y=0.38021, confidence=1.00)
# LEFT_KNEE: (x=0.50901, y=0.52796, confidence=1.00)
# LEFT_ANKLE: (x=0.55298, y=0.66137, confidence=1.00)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.43561, y=0.28200, confidence=1.00)
# LEFT_ELBOW: (x=0.46852, y=0.36742, confidence=1.00)
# LEFT_WRIST: (x=0.42739, y=0.41546, confidence=1.00)
# LEFT_HIP: (x=0.52760, y=0.36608, confidence=1.00)
# LEFT_KNEE: (x=0.51040, y=0.52491, confidence=1.00)
# LEFT_ANKLE: (x=0.55826, y=0.67172, confidence=1.00)
# Pose classified as non-cycling. Using weights: {'LEFT_SHOULDER': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_ELBOW': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_WRIST': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_HIP': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_KNEE': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_ANKLE': {'mediapipe': 0.3, 'rcnn': 0.7}}
# LEFT_SHOULDER - MediaPipe Consistency: 0.98, R-CNN Consistency: 0.98
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.97, R-CNN Consistency: 0.98
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.97, R-CNN Consistency: 0.99
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_HIP: Using R-CNN prediction.
# LEFT_KNEE - MediaPipe Consistency: 1.00, R-CNN Consistency: 1.00
# LEFT_KNEE: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_ANKLE - MediaPipe Consistency: 1.00, R-CNN Consistency: 1.00
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.43561, y=0.28200, confidence=1.00)
# LEFT_ELBOW: (x=0.47080, y=0.36265, confidence=1.00)
# LEFT_WRIST: (x=0.42739, y=0.41546, confidence=1.00)
# LEFT_HIP: (x=0.52760, y=0.36608, confidence=1.00)
# LEFT_KNEE: (x=0.50970, y=0.52643, confidence=1.00)
# LEFT_ANKLE: (x=0.55826, y=0.67172, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\checkdataset_final_output_grok3\15.png
#
# Processing 16.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.49708, y=0.30055, confidence=1.00)
# LEFT_ELBOW: (x=0.47354, y=0.38626, confidence=0.94)
# LEFT_WRIST: (x=0.42097, y=0.37379, confidence=0.95)
# LEFT_HIP: (x=0.56491, y=0.40256, confidence=1.00)
# LEFT_KNEE: (x=0.48337, y=0.42964, confidence=0.96)
# LEFT_ANKLE: (x=0.52181, y=0.56636, confidence=0.96)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.48726, y=0.30664, confidence=1.00)
# LEFT_ELBOW: (x=0.47230, y=0.39192, confidence=1.00)
# LEFT_WRIST: (x=0.41917, y=0.37460, confidence=1.00)
# LEFT_HIP: (x=0.55984, y=0.39059, confidence=1.00)
# LEFT_KNEE: (x=0.48352, y=0.43323, confidence=1.00)
# LEFT_ANKLE: (x=0.53515, y=0.54783, confidence=1.00)
# Pose classified as cycling. Using weights: {'LEFT_SHOULDER': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_ELBOW': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_WRIST': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_HIP': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_KNEE': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_ANKLE': {'mediapipe': 0.3, 'rcnn': 0.7}}
# LEFT_SHOULDER - MediaPipe Consistency: 0.98, R-CNN Consistency: 0.98
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.94, R-CNN Consistency: 0.98
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.95, R-CNN Consistency: 0.98
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 0.97, R-CNN Consistency: 0.97
# LEFT_HIP: Using R-CNN prediction.
# LEFT_KNEE - MediaPipe Consistency: 0.94, R-CNN Consistency: 0.97
# LEFT_KNEE: Using R-CNN prediction.
# LEFT_ANKLE - MediaPipe Consistency: 0.94, R-CNN Consistency: 0.97
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.48726, y=0.30664, confidence=1.00)
# LEFT_ELBOW: (x=0.47292, y=0.38909, confidence=1.00)
# LEFT_WRIST: (x=0.41917, y=0.37460, confidence=1.00)
# LEFT_HIP: (x=0.55984, y=0.39059, confidence=1.00)
# LEFT_KNEE: (x=0.48352, y=0.43323, confidence=1.00)
# LEFT_ANKLE: (x=0.53515, y=0.54783, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\checkdataset_final_output_grok3\16.png
#
# Processing 17.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.50952, y=0.29581, confidence=1.00)
# LEFT_ELBOW: (x=0.49271, y=0.38534, confidence=0.98)
# LEFT_WRIST: (x=0.44026, y=0.42870, confidence=0.98)
# LEFT_HIP: (x=0.56509, y=0.40486, confidence=0.99)
# LEFT_KNEE: (x=0.48580, y=0.42777, confidence=0.95)
# LEFT_ANKLE: (x=0.52832, y=0.54607, confidence=0.90)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.50165, y=0.29364, confidence=1.00)
# LEFT_ELBOW: (x=0.48369, y=0.39766, confidence=1.00)
# LEFT_WRIST: (x=0.43580, y=0.43367, confidence=1.00)
# LEFT_HIP: (x=0.55927, y=0.39099, confidence=1.00)
# LEFT_KNEE: (x=0.48369, y=0.44167, confidence=1.00)
# LEFT_ANKLE: (x=0.53533, y=0.54970, confidence=1.00)
# Pose classified as cycling. Using weights: {'LEFT_SHOULDER': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_ELBOW': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_WRIST': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_HIP': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_KNEE': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_ANKLE': {'mediapipe': 0.3, 'rcnn': 0.7}}
# LEFT_SHOULDER - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.98, R-CNN Consistency: 0.99
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.97, R-CNN Consistency: 0.99
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 0.96, R-CNN Consistency: 0.96
# LEFT_HIP: Using R-CNN prediction.
# LEFT_KNEE - MediaPipe Consistency: 0.92, R-CNN Consistency: 0.96
# LEFT_KNEE: Using R-CNN prediction.
# LEFT_ANKLE - MediaPipe Consistency: 0.91, R-CNN Consistency: 0.98
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.50165, y=0.29364, confidence=1.00)
# LEFT_ELBOW: (x=0.48820, y=0.39150, confidence=1.00)
# LEFT_WRIST: (x=0.43580, y=0.43367, confidence=1.00)
# LEFT_HIP: (x=0.55927, y=0.39099, confidence=1.00)
# LEFT_KNEE: (x=0.48369, y=0.44167, confidence=1.00)
# LEFT_ANKLE: (x=0.53533, y=0.54970, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\checkdataset_final_output_grok3\17.png
#
# Processing 18.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.45789, y=0.25575, confidence=1.00)
# LEFT_ELBOW: (x=0.46764, y=0.33868, confidence=0.99)
# LEFT_WRIST: (x=0.42140, y=0.37444, confidence=0.96)
# LEFT_HIP: (x=0.51323, y=0.40294, confidence=1.00)
# LEFT_KNEE: (x=0.50788, y=0.54494, confidence=0.99)
# LEFT_ANKLE: (x=0.54508, y=0.68599, confidence=0.99)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.46129, y=0.24283, confidence=1.00)
# LEFT_ELBOW: (x=0.46802, y=0.33622, confidence=1.00)
# LEFT_WRIST: (x=0.42389, y=0.37223, confidence=1.00)
# LEFT_HIP: (x=0.51140, y=0.39758, confidence=1.00)
# LEFT_KNEE: (x=0.50991, y=0.54700, confidence=1.00)
# LEFT_ANKLE: (x=0.54581, y=0.68307, confidence=1.00)
# Pose classified as non-cycling. Using weights: {'LEFT_SHOULDER': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_ELBOW': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_WRIST': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_HIP': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_KNEE': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_ANKLE': {'mediapipe': 0.3, 'rcnn': 0.7}}
# LEFT_SHOULDER - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.98, R-CNN Consistency: 0.99
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.97, R-CNN Consistency: 0.99
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_HIP: Using R-CNN prediction.
# LEFT_KNEE - MediaPipe Consistency: 0.99, R-CNN Consistency: 1.00
# LEFT_KNEE: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_ANKLE - MediaPipe Consistency: 0.99, R-CNN Consistency: 1.00
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.46129, y=0.24283, confidence=1.00)
# LEFT_ELBOW: (x=0.46783, y=0.33745, confidence=1.00)
# LEFT_WRIST: (x=0.42389, y=0.37223, confidence=1.00)
# LEFT_HIP: (x=0.51140, y=0.39758, confidence=1.00)
# LEFT_KNEE: (x=0.50889, y=0.54597, confidence=1.00)
# LEFT_ANKLE: (x=0.54581, y=0.68307, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\checkdataset_final_output_grok3\18.png
#
# Processing 19.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.44388, y=0.31926, confidence=1.00)
# LEFT_ELBOW: (x=0.47434, y=0.37369, confidence=0.98)
# LEFT_WRIST: (x=0.43566, y=0.43251, confidence=0.99)
# LEFT_HIP: (x=0.53103, y=0.39595, confidence=1.00)
# LEFT_KNEE: (x=0.52437, y=0.54113, confidence=0.98)
# LEFT_ANKLE: (x=0.53405, y=0.68256, confidence=0.99)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.44946, y=0.31006, confidence=1.00)
# LEFT_ELBOW: (x=0.47415, y=0.38613, confidence=1.00)
# LEFT_WRIST: (x=0.43674, y=0.43018, confidence=1.00)
# LEFT_HIP: (x=0.53923, y=0.38480, confidence=1.00)
# LEFT_KNEE: (x=0.52652, y=0.53961, confidence=1.00)
# LEFT_ANKLE: (x=0.53923, y=0.68642, confidence=1.00)
# Pose classified as non-cycling. Using weights: {'LEFT_SHOULDER': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_ELBOW': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_WRIST': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_HIP': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_KNEE': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_ANKLE': {'mediapipe': 0.3, 'rcnn': 0.7}}
# LEFT_SHOULDER - MediaPipe Consistency: 0.98, R-CNN Consistency: 0.98
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.96, R-CNN Consistency: 0.97
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.97, R-CNN Consistency: 0.97
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_HIP: Using R-CNN prediction.
# Knee angle warning: 173.44 degrees (extreme angle detected).
# Knee angle warning: 170.34 degrees (extreme angle detected).
# LEFT_KNEE - MediaPipe Consistency: 0.92, R-CNN Consistency: 0.94
# LEFT_KNEE: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_ANKLE - MediaPipe Consistency: 0.99, R-CNN Consistency: 1.00
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.44946, y=0.31006, confidence=1.00)
# LEFT_ELBOW: (x=0.47425, y=0.37991, confidence=1.00)
# LEFT_WRIST: (x=0.43674, y=0.43018, confidence=1.00)
# LEFT_HIP: (x=0.53923, y=0.38480, confidence=1.00)
# LEFT_KNEE: (x=0.52544, y=0.54037, confidence=1.00)
# LEFT_ANKLE: (x=0.53923, y=0.68642, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\checkdataset_final_output_grok3\19.png
#
# Processing 2.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.46631, y=0.29565, confidence=1.00)
# LEFT_ELBOW: (x=0.48627, y=0.39472, confidence=0.93)
# LEFT_WRIST: (x=0.43109, y=0.41769, confidence=0.97)
# LEFT_HIP: (x=0.55593, y=0.37075, confidence=1.00)
# LEFT_KNEE: (x=0.48080, y=0.42353, confidence=0.96)
# LEFT_ANKLE: (x=0.50961, y=0.57782, confidence=0.97)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.46534, y=0.29509, confidence=1.00)
# LEFT_ELBOW: (x=0.47883, y=0.38849, confidence=1.00)
# LEFT_WRIST: (x=0.42560, y=0.42318, confidence=1.00)
# LEFT_HIP: (x=0.55905, y=0.37248, confidence=1.00)
# LEFT_KNEE: (x=0.47583, y=0.42986, confidence=1.00)
# LEFT_ANKLE: (x=0.50582, y=0.56596, confidence=1.00)
# Pose classified as cycling. Using weights: {'LEFT_SHOULDER': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_ELBOW': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_WRIST': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_HIP': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_KNEE': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_ANKLE': {'mediapipe': 0.3, 'rcnn': 0.7}}
# LEFT_SHOULDER - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.93, R-CNN Consistency: 0.98
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.94, R-CNN Consistency: 0.96
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 1.00, R-CNN Consistency: 1.00
# LEFT_HIP: Using R-CNN prediction.
# LEFT_KNEE - MediaPipe Consistency: 0.97, R-CNN Consistency: 1.00
# LEFT_KNEE: Using R-CNN prediction.
# LEFT_ANKLE - MediaPipe Consistency: 0.97, R-CNN Consistency: 0.99
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.46534, y=0.29509, confidence=1.00)
# LEFT_ELBOW: (x=0.48255, y=0.39161, confidence=1.00)
# LEFT_WRIST: (x=0.42560, y=0.42318, confidence=1.00)
# LEFT_HIP: (x=0.55905, y=0.37248, confidence=1.00)
# LEFT_KNEE: (x=0.47583, y=0.42986, confidence=1.00)
# LEFT_ANKLE: (x=0.50582, y=0.56596, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\checkdataset_final_output_grok3\2.png
#
# Processing 20.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.52559, y=0.24695, confidence=1.00)
# LEFT_ELBOW: (x=0.49015, y=0.32976, confidence=1.00)
# LEFT_WRIST: (x=0.44203, y=0.38155, confidence=0.99)
# LEFT_HIP: (x=0.55693, y=0.41135, confidence=1.00)
# LEFT_KNEE: (x=0.51653, y=0.53122, confidence=0.99)
# LEFT_ANKLE: (x=0.55423, y=0.66313, confidence=0.99)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.53098, y=0.24526, confidence=1.00)
# LEFT_ELBOW: (x=0.48612, y=0.32794, confidence=1.00)
# LEFT_WRIST: (x=0.44424, y=0.38796, confidence=1.00)
# LEFT_HIP: (x=0.55865, y=0.40930, confidence=1.00)
# LEFT_KNEE: (x=0.51378, y=0.53200, confidence=1.00)
# LEFT_ANKLE: (x=0.55715, y=0.66536, confidence=1.00)
# Pose classified as cycling. Using weights: {'LEFT_SHOULDER': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_ELBOW': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_WRIST': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_HIP': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_KNEE': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_ANKLE': {'mediapipe': 0.3, 'rcnn': 0.7}}
# LEFT_SHOULDER - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.97, R-CNN Consistency: 0.98
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.96, R-CNN Consistency: 0.97
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 1.00, R-CNN Consistency: 1.00
# LEFT_HIP: Using R-CNN prediction.
# LEFT_KNEE - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_KNEE: Using R-CNN prediction.
# LEFT_ANKLE - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.53098, y=0.24526, confidence=1.00)
# LEFT_ELBOW: (x=0.48813, y=0.32885, confidence=1.00)
# LEFT_WRIST: (x=0.44424, y=0.38796, confidence=1.00)
# LEFT_HIP: (x=0.55865, y=0.40930, confidence=1.00)
# LEFT_KNEE: (x=0.51378, y=0.53200, confidence=1.00)
# LEFT_ANKLE: (x=0.55715, y=0.66536, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\checkdataset_final_output_grok3\20.png
#
# Processing 21.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.47029, y=0.28893, confidence=1.00)
# LEFT_ELBOW: (x=0.45470, y=0.39345, confidence=0.95)
# LEFT_WRIST: (x=0.40980, y=0.36614, confidence=0.95)
# LEFT_HIP: (x=0.55629, y=0.37877, confidence=1.00)
# LEFT_KNEE: (x=0.47673, y=0.43045, confidence=0.95)
# LEFT_ANKLE: (x=0.53881, y=0.52267, confidence=0.87)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.46848, y=0.28698, confidence=1.00)
# LEFT_ELBOW: (x=0.45951, y=0.39220, confidence=1.00)
# LEFT_WRIST: (x=0.40940, y=0.36423, confidence=1.00)
# LEFT_HIP: (x=0.54701, y=0.36423, confidence=1.00)
# LEFT_KNEE: (x=0.47671, y=0.43615, confidence=1.00)
# LEFT_ANKLE: (x=0.54402, y=0.53205, confidence=1.00)
# Pose classified as cycling. Using weights: {'LEFT_SHOULDER': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_ELBOW': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_WRIST': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_HIP': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_KNEE': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_ANKLE': {'mediapipe': 0.3, 'rcnn': 0.7}}
# LEFT_SHOULDER - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.95, R-CNN Consistency: 0.99
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.96, R-CNN Consistency: 0.99
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 0.97, R-CNN Consistency: 0.97
# LEFT_HIP: Using R-CNN prediction.
# LEFT_KNEE - MediaPipe Consistency: 0.94, R-CNN Consistency: 0.97
# LEFT_KNEE: Using R-CNN prediction.
# LEFT_ANKLE - MediaPipe Consistency: 0.90, R-CNN Consistency: 1.00
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.46848, y=0.28698, confidence=1.00)
# LEFT_ELBOW: (x=0.45710, y=0.39283, confidence=1.00)
# LEFT_WRIST: (x=0.40940, y=0.36423, confidence=1.00)
# LEFT_HIP: (x=0.54701, y=0.36423, confidence=1.00)
# LEFT_KNEE: (x=0.47671, y=0.43615, confidence=1.00)
# LEFT_ANKLE: (x=0.54402, y=0.53205, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\checkdataset_final_output_grok3\21.png
#
# Processing 22.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.46925, y=0.29446, confidence=1.00)
# LEFT_ELBOW: (x=0.47645, y=0.40077, confidence=0.93)
# LEFT_WRIST: (x=0.42428, y=0.41261, confidence=0.98)
# LEFT_HIP: (x=0.55614, y=0.37649, confidence=1.00)
# LEFT_KNEE: (x=0.47436, y=0.41599, confidence=0.98)
# LEFT_ANKLE: (x=0.53470, y=0.52154, confidence=0.93)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.46894, y=0.29012, confidence=1.00)
# LEFT_ELBOW: (x=0.47269, y=0.39922, confidence=1.00)
# LEFT_WRIST: (x=0.42255, y=0.41385, confidence=1.00)
# LEFT_HIP: (x=0.54676, y=0.36596, confidence=1.00)
# LEFT_KNEE: (x=0.47343, y=0.42849, confidence=1.00)
# LEFT_ANKLE: (x=0.54003, y=0.52960, confidence=1.00)
# Pose classified as cycling. Using weights: {'LEFT_SHOULDER': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_ELBOW': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_WRIST': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_HIP': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_KNEE': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_ANKLE': {'mediapipe': 0.3, 'rcnn': 0.7}}
# LEFT_SHOULDER - MediaPipe Consistency: 1.00, R-CNN Consistency: 1.00
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.94, R-CNN Consistency: 0.99
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.97, R-CNN Consistency: 0.99
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 0.97, R-CNN Consistency: 0.97
# LEFT_HIP: Using R-CNN prediction.
# LEFT_KNEE - MediaPipe Consistency: 0.95, R-CNN Consistency: 0.97
# LEFT_KNEE: Using R-CNN prediction.
# LEFT_ANKLE - MediaPipe Consistency: 0.94, R-CNN Consistency: 0.99
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.46894, y=0.29012, confidence=1.00)
# LEFT_ELBOW: (x=0.47457, y=0.39999, confidence=1.00)
# LEFT_WRIST: (x=0.42255, y=0.41385, confidence=1.00)
# LEFT_HIP: (x=0.54676, y=0.36596, confidence=1.00)
# LEFT_KNEE: (x=0.47343, y=0.42849, confidence=1.00)
# LEFT_ANKLE: (x=0.54003, y=0.52960, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\checkdataset_final_output_grok3\22.png
#
# Processing 23.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.45815, y=0.24125, confidence=1.00)
# LEFT_ELBOW: (x=0.47565, y=0.34412, confidence=0.99)
# LEFT_WRIST: (x=0.42263, y=0.36855, confidence=0.99)
# LEFT_HIP: (x=0.53356, y=0.37820, confidence=1.00)
# LEFT_KNEE: (x=0.53167, y=0.52926, confidence=0.98)
# LEFT_ANKLE: (x=0.53743, y=0.66261, confidence=0.97)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.45700, y=0.23028, confidence=1.00)
# LEFT_ELBOW: (x=0.47124, y=0.34748, confidence=1.00)
# LEFT_WRIST: (x=0.41878, y=0.36347, confidence=1.00)
# LEFT_HIP: (x=0.53119, y=0.36080, confidence=1.00)
# LEFT_KNEE: (x=0.53044, y=0.51797, confidence=1.00)
# LEFT_ANKLE: (x=0.53793, y=0.66981, confidence=1.00)
# Pose classified as non-cycling. Using weights: {'LEFT_SHOULDER': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_ELBOW': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_WRIST': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_HIP': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_KNEE': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_ANKLE': {'mediapipe': 0.3, 'rcnn': 0.7}}
# LEFT_SHOULDER - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.98, R-CNN Consistency: 0.98
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.97, R-CNN Consistency: 0.97
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 1.00, R-CNN Consistency: 1.00
# LEFT_HIP: Using R-CNN prediction.
# Knee angle warning: 176.76 degrees (extreme angle detected).
# Knee angle warning: 176.86 degrees (extreme angle detected).
# LEFT_KNEE - MediaPipe Consistency: 0.92, R-CNN Consistency: 0.94
# LEFT_KNEE: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_ANKLE - MediaPipe Consistency: 0.98, R-CNN Consistency: 1.00
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.45700, y=0.23028, confidence=1.00)
# LEFT_ELBOW: (x=0.47344, y=0.34580, confidence=1.00)
# LEFT_WRIST: (x=0.41878, y=0.36347, confidence=1.00)
# LEFT_HIP: (x=0.53119, y=0.36080, confidence=1.00)
# LEFT_KNEE: (x=0.53105, y=0.52361, confidence=1.00)
# LEFT_ANKLE: (x=0.53793, y=0.66981, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\checkdataset_final_output_grok3\23.png
#
# Processing 24.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.44169, y=0.26888, confidence=1.00)
# LEFT_ELBOW: (x=0.46209, y=0.33884, confidence=0.98)
# LEFT_WRIST: (x=0.42357, y=0.42239, confidence=0.97)
# LEFT_HIP: (x=0.52496, y=0.36997, confidence=1.00)
# LEFT_KNEE: (x=0.45358, y=0.45009, confidence=0.92)
# LEFT_ANKLE: (x=0.52725, y=0.52809, confidence=0.84)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.43718, y=0.26462, confidence=1.00)
# LEFT_ELBOW: (x=0.46036, y=0.33652, confidence=1.00)
# LEFT_WRIST: (x=0.43045, y=0.41906, confidence=1.00)
# LEFT_HIP: (x=0.51942, y=0.35782, confidence=1.00)
# LEFT_KNEE: (x=0.45737, y=0.44835, confidence=1.00)
# LEFT_ANKLE: (x=0.52316, y=0.52291, confidence=1.00)
# Pose classified as cycling. Using weights: {'LEFT_SHOULDER': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_ELBOW': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_WRIST': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_HIP': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_KNEE': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_ANKLE': {'mediapipe': 0.3, 'rcnn': 0.7}}
# LEFT_SHOULDER - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.97, R-CNN Consistency: 0.99
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.96, R-CNN Consistency: 0.98
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 0.98, R-CNN Consistency: 0.98
# LEFT_HIP: Using R-CNN prediction.
# LEFT_KNEE - MediaPipe Consistency: 0.93, R-CNN Consistency: 0.98
# LEFT_KNEE: Using R-CNN prediction.
# LEFT_ANKLE - MediaPipe Consistency: 0.88, R-CNN Consistency: 0.99
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.43718, y=0.26462, confidence=1.00)
# LEFT_ELBOW: (x=0.46122, y=0.33768, confidence=1.00)
# LEFT_WRIST: (x=0.43045, y=0.41906, confidence=1.00)
# LEFT_HIP: (x=0.51942, y=0.35782, confidence=1.00)
# LEFT_KNEE: (x=0.45737, y=0.44835, confidence=1.00)
# LEFT_ANKLE: (x=0.52316, y=0.52291, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\checkdataset_final_output_grok3\24.png
#
# Processing 25.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.50190, y=0.21519, confidence=1.00)
# LEFT_ELBOW: (x=0.46846, y=0.30893, confidence=0.99)
# LEFT_WRIST: (x=0.42879, y=0.36777, confidence=0.97)
# LEFT_HIP: (x=0.55735, y=0.38378, confidence=1.00)
# LEFT_KNEE: (x=0.52672, y=0.51505, confidence=0.99)
# LEFT_ANKLE: (x=0.53636, y=0.66051, confidence=0.99)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.50815, y=0.20409, confidence=1.00)
# LEFT_ELBOW: (x=0.46999, y=0.29349, confidence=1.00)
# LEFT_WRIST: (x=0.42959, y=0.36555, confidence=1.00)
# LEFT_HIP: (x=0.55154, y=0.38690, confidence=1.00)
# LEFT_KNEE: (x=0.52386, y=0.52167, confidence=1.00)
# LEFT_ANKLE: (x=0.53883, y=0.67913, confidence=1.00)
# Pose classified as non-cycling. Using weights: {'LEFT_SHOULDER': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_ELBOW': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_WRIST': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_HIP': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_KNEE': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_ANKLE': {'mediapipe': 0.3, 'rcnn': 0.7}}
# LEFT_SHOULDER - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.98, R-CNN Consistency: 0.99
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.96, R-CNN Consistency: 0.98
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_HIP: Using R-CNN prediction.
# LEFT_KNEE - MediaPipe Consistency: 0.99, R-CNN Consistency: 1.00
# LEFT_KNEE: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_ANKLE - MediaPipe Consistency: 0.99, R-CNN Consistency: 1.00
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.50815, y=0.20409, confidence=1.00)
# LEFT_ELBOW: (x=0.46923, y=0.30121, confidence=1.00)
# LEFT_WRIST: (x=0.42959, y=0.36555, confidence=1.00)
# LEFT_HIP: (x=0.55154, y=0.38690, confidence=1.00)
# LEFT_KNEE: (x=0.52529, y=0.51836, confidence=1.00)
# LEFT_ANKLE: (x=0.53883, y=0.67913, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\checkdataset_final_output_grok3\25.png
#
# Processing 3.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.48497, y=0.21250, confidence=1.00)
# LEFT_ELBOW: (x=0.46733, y=0.31584, confidence=0.98)
# LEFT_WRIST: (x=0.42050, y=0.36803, confidence=0.98)
# LEFT_HIP: (x=0.56478, y=0.35325, confidence=1.00)
# LEFT_KNEE: (x=0.54114, y=0.49888, confidence=0.99)
# LEFT_ANKLE: (x=0.56673, y=0.65836, confidence=1.00)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.48857, y=0.19333, confidence=1.00)
# LEFT_ELBOW: (x=0.47137, y=0.30666, confidence=1.00)
# LEFT_WRIST: (x=0.42575, y=0.36666, confidence=1.00)
# LEFT_HIP: (x=0.56262, y=0.33733, confidence=1.00)
# LEFT_KNEE: (x=0.53719, y=0.49866, confidence=1.00)
# LEFT_ANKLE: (x=0.56486, y=0.65598, confidence=1.00)
# Pose classified as non-cycling. Using weights: {'LEFT_SHOULDER': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_ELBOW': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_WRIST': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_HIP': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_KNEE': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_ANKLE': {'mediapipe': 0.3, 'rcnn': 0.7}}
# LEFT_SHOULDER - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.98, R-CNN Consistency: 0.99
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.97, R-CNN Consistency: 0.98
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 0.99, R-CNN Consistency: 1.00
# LEFT_HIP: Using R-CNN prediction.
# LEFT_KNEE - MediaPipe Consistency: 0.99, R-CNN Consistency: 1.00
# LEFT_KNEE: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_ANKLE - MediaPipe Consistency: 0.99, R-CNN Consistency: 1.00
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.48857, y=0.19333, confidence=1.00)
# LEFT_ELBOW: (x=0.46935, y=0.31125, confidence=1.00)
# LEFT_WRIST: (x=0.42575, y=0.36666, confidence=1.00)
# LEFT_HIP: (x=0.56262, y=0.33733, confidence=1.00)
# LEFT_KNEE: (x=0.53916, y=0.49877, confidence=1.00)
# LEFT_ANKLE: (x=0.56486, y=0.65598, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\checkdataset_final_output_grok3\3.png
#
# Processing 4.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.43457, y=0.27368, confidence=1.00)
# LEFT_ELBOW: (x=0.47258, y=0.32495, confidence=0.91)
# LEFT_WRIST: (x=0.42416, y=0.37255, confidence=0.85)
# LEFT_HIP: (x=0.53380, y=0.37027, confidence=1.00)
# LEFT_KNEE: (x=0.52592, y=0.51917, confidence=0.99)
# LEFT_ANKLE: (x=0.54401, y=0.67718, confidence=0.99)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.42898, y=0.27405, confidence=1.00)
# LEFT_ELBOW: (x=0.46947, y=0.32067, confidence=1.00)
# LEFT_WRIST: (x=0.42673, y=0.37396, confidence=1.00)
# LEFT_HIP: (x=0.53396, y=0.35797, confidence=1.00)
# LEFT_KNEE: (x=0.52272, y=0.51782, confidence=1.00)
# LEFT_ANKLE: (x=0.54521, y=0.67901, confidence=1.00)
# Pose classified as non-cycling. Using weights: {'LEFT_SHOULDER': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_ELBOW': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_WRIST': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_HIP': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_KNEE': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_ANKLE': {'mediapipe': 0.3, 'rcnn': 0.7}}
# LEFT_SHOULDER - MediaPipe Consistency: 0.98, R-CNN Consistency: 0.98
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.92, R-CNN Consistency: 0.98
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.87, R-CNN Consistency: 0.98
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_HIP: Using R-CNN prediction.
# Knee angle warning: 170.42 degrees (extreme angle detected).
# LEFT_KNEE - MediaPipe Consistency: 0.93, R-CNN Consistency: 1.00
# LEFT_KNEE: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_ANKLE - MediaPipe Consistency: 0.99, R-CNN Consistency: 1.00
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.42898, y=0.27405, confidence=1.00)
# LEFT_ELBOW: (x=0.47102, y=0.32281, confidence=1.00)
# LEFT_WRIST: (x=0.42673, y=0.37396, confidence=1.00)
# LEFT_HIP: (x=0.53396, y=0.35797, confidence=1.00)
# LEFT_KNEE: (x=0.52432, y=0.51850, confidence=1.00)
# LEFT_ANKLE: (x=0.54521, y=0.67901, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\checkdataset_final_output_grok3\4.png
#
# Processing 5.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.49704, y=0.22053, confidence=1.00)
# LEFT_ELBOW: (x=0.45954, y=0.31145, confidence=0.99)
# LEFT_WRIST: (x=0.41263, y=0.36665, confidence=0.99)
# LEFT_HIP: (x=0.56757, y=0.38307, confidence=1.00)
# LEFT_KNEE: (x=0.52701, y=0.51788, confidence=0.98)
# LEFT_ANKLE: (x=0.53469, y=0.67182, confidence=0.99)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.50025, y=0.20916, confidence=1.00)
# LEFT_ELBOW: (x=0.46658, y=0.30379, confidence=1.00)
# LEFT_WRIST: (x=0.41869, y=0.36243, confidence=1.00)
# LEFT_HIP: (x=0.56610, y=0.37176, confidence=1.00)
# LEFT_KNEE: (x=0.52644, y=0.51970, confidence=1.00)
# LEFT_ANKLE: (x=0.53542, y=0.68097, confidence=1.00)
# Pose classified as non-cycling. Using weights: {'LEFT_SHOULDER': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_ELBOW': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_WRIST': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_HIP': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_KNEE': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_ANKLE': {'mediapipe': 0.3, 'rcnn': 0.7}}
# LEFT_SHOULDER - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.99, R-CNN Consistency: 1.00
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_HIP: Using R-CNN prediction.
# LEFT_KNEE - MediaPipe Consistency: 0.98, R-CNN Consistency: 1.00
# LEFT_KNEE: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_ANKLE - MediaPipe Consistency: 0.99, R-CNN Consistency: 1.00
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.50025, y=0.20916, confidence=1.00)
# LEFT_ELBOW: (x=0.46306, y=0.30762, confidence=1.00)
# LEFT_WRIST: (x=0.41869, y=0.36243, confidence=1.00)
# LEFT_HIP: (x=0.56610, y=0.37176, confidence=1.00)
# LEFT_KNEE: (x=0.52673, y=0.51879, confidence=1.00)
# LEFT_ANKLE: (x=0.53542, y=0.68097, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\checkdataset_final_output_grok3\5.png
#
# Processing 6.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.50129, y=0.22351, confidence=1.00)
# LEFT_ELBOW: (x=0.46737, y=0.31046, confidence=0.99)
# LEFT_WRIST: (x=0.42386, y=0.36745, confidence=0.98)
# LEFT_HIP: (x=0.55739, y=0.37446, confidence=1.00)
# LEFT_KNEE: (x=0.49281, y=0.46779, confidence=0.99)
# LEFT_ANKLE: (x=0.51443, y=0.61088, confidence=0.98)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.50577, y=0.21332, confidence=1.00)
# LEFT_ELBOW: (x=0.47061, y=0.28806, confidence=1.00)
# LEFT_WRIST: (x=0.42349, y=0.36412, confidence=1.00)
# LEFT_HIP: (x=0.56112, y=0.36813, confidence=1.00)
# LEFT_KNEE: (x=0.48857, y=0.45887, confidence=1.00)
# LEFT_ANKLE: (x=0.50801, y=0.62168, confidence=1.00)
# Pose classified as cycling. Using weights: {'LEFT_SHOULDER': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_ELBOW': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_WRIST': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_HIP': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_KNEE': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_ANKLE': {'mediapipe': 0.3, 'rcnn': 0.7}}
# LEFT_SHOULDER - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.98, R-CNN Consistency: 0.98
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.97, R-CNN Consistency: 0.98
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_HIP: Using R-CNN prediction.
# LEFT_KNEE - MediaPipe Consistency: 0.98, R-CNN Consistency: 0.99
# LEFT_KNEE: Using R-CNN prediction.
# LEFT_ANKLE - MediaPipe Consistency: 0.98, R-CNN Consistency: 0.99
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.50577, y=0.21332, confidence=1.00)
# LEFT_ELBOW: (x=0.46899, y=0.29926, confidence=1.00)
# LEFT_WRIST: (x=0.42349, y=0.36412, confidence=1.00)
# LEFT_HIP: (x=0.56112, y=0.36813, confidence=1.00)
# LEFT_KNEE: (x=0.48857, y=0.45887, confidence=1.00)
# LEFT_ANKLE: (x=0.50801, y=0.62168, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\checkdataset_final_output_grok3\6.png
#
# Processing 7.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.49698, y=0.31565, confidence=1.00)
# LEFT_ELBOW: (x=0.49062, y=0.41643, confidence=0.95)
# LEFT_WRIST: (x=0.44044, y=0.43468, confidence=0.96)
# LEFT_HIP: (x=0.56045, y=0.41195, confidence=1.00)
# LEFT_KNEE: (x=0.49505, y=0.47457, confidence=0.97)
# LEFT_ANKLE: (x=0.51131, y=0.60969, confidence=0.96)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.49770, y=0.32327, confidence=1.00)
# LEFT_ELBOW: (x=0.48647, y=0.42449, confidence=1.00)
# LEFT_WRIST: (x=0.43855, y=0.43914, confidence=1.00)
# LEFT_HIP: (x=0.55836, y=0.40185, confidence=1.00)
# LEFT_KNEE: (x=0.49097, y=0.46444, confidence=1.00)
# LEFT_ANKLE: (x=0.50145, y=0.60694, confidence=1.00)
# Pose classified as cycling. Using weights: {'LEFT_SHOULDER': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_ELBOW': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_WRIST': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_HIP': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_KNEE': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_ANKLE': {'mediapipe': 0.3, 'rcnn': 0.7}}
# LEFT_SHOULDER - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.96, R-CNN Consistency: 0.99
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.97, R-CNN Consistency: 0.99
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_HIP: Using R-CNN prediction.
# LEFT_KNEE - MediaPipe Consistency: 0.97, R-CNN Consistency: 0.99
# LEFT_KNEE: Using R-CNN prediction.
# LEFT_ANKLE - MediaPipe Consistency: 0.96, R-CNN Consistency: 0.99
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.49770, y=0.32327, confidence=1.00)
# LEFT_ELBOW: (x=0.48855, y=0.42046, confidence=1.00)
# LEFT_WRIST: (x=0.43855, y=0.43914, confidence=1.00)
# LEFT_HIP: (x=0.55836, y=0.40185, confidence=1.00)
# LEFT_KNEE: (x=0.49097, y=0.46444, confidence=1.00)
# LEFT_ANKLE: (x=0.50145, y=0.60694, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\checkdataset_final_output_grok3\7.png
#
# Processing 8.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.52497, y=0.20644, confidence=1.00)
# LEFT_ELBOW: (x=0.48625, y=0.28218, confidence=0.99)
# LEFT_WRIST: (x=0.43119, y=0.33219, confidence=0.98)
# LEFT_HIP: (x=0.55505, y=0.36039, confidence=1.00)
# LEFT_KNEE: (x=0.48451, y=0.44475, confidence=0.99)
# LEFT_ANKLE: (x=0.50504, y=0.59913, confidence=0.99)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.52845, y=0.19844, confidence=1.00)
# LEFT_ELBOW: (x=0.48951, y=0.27978, confidence=1.00)
# LEFT_WRIST: (x=0.42961, y=0.33578, confidence=1.00)
# LEFT_HIP: (x=0.56065, y=0.35445, confidence=1.00)
# LEFT_KNEE: (x=0.48277, y=0.44379, confidence=1.00)
# LEFT_ANKLE: (x=0.50224, y=0.61313, confidence=1.00)
# Pose classified as cycling. Using weights: {'LEFT_SHOULDER': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_ELBOW': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_WRIST': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_HIP': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_KNEE': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_ANKLE': {'mediapipe': 0.3, 'rcnn': 0.7}}
# LEFT_SHOULDER - MediaPipe Consistency: 1.00, R-CNN Consistency: 1.00
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.99, R-CNN Consistency: 1.00
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.98, R-CNN Consistency: 1.00
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 1.00, R-CNN Consistency: 1.00
# LEFT_HIP: Using R-CNN prediction.
# LEFT_KNEE - MediaPipe Consistency: 0.99, R-CNN Consistency: 1.00
# LEFT_KNEE: Using R-CNN prediction.
# LEFT_ANKLE - MediaPipe Consistency: 0.99, R-CNN Consistency: 1.00
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.52845, y=0.19844, confidence=1.00)
# LEFT_ELBOW: (x=0.48788, y=0.28098, confidence=1.00)
# LEFT_WRIST: (x=0.42961, y=0.33578, confidence=1.00)
# LEFT_HIP: (x=0.56065, y=0.35445, confidence=1.00)
# LEFT_KNEE: (x=0.48277, y=0.44379, confidence=1.00)
# LEFT_ANKLE: (x=0.50224, y=0.61313, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\checkdataset_final_output_grok3\8.png
#
# Processing 9.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.51783, y=0.22678, confidence=1.00)
# LEFT_ELBOW: (x=0.48397, y=0.31160, confidence=0.99)
# LEFT_WRIST: (x=0.43543, y=0.36532, confidence=0.99)
# LEFT_HIP: (x=0.56756, y=0.37982, confidence=1.00)
# LEFT_KNEE: (x=0.49568, y=0.47582, confidence=0.94)
# LEFT_ANKLE: (x=0.50530, y=0.62931, confidence=0.95)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.52071, y=0.22093, confidence=1.00)
# LEFT_ELBOW: (x=0.48329, y=0.31286, confidence=1.00)
# LEFT_WRIST: (x=0.43614, y=0.37015, confidence=1.00)
# LEFT_HIP: (x=0.56487, y=0.36882, confidence=1.00)
# LEFT_KNEE: (x=0.49078, y=0.47140, confidence=1.00)
# LEFT_ANKLE: (x=0.50724, y=0.64593, confidence=1.00)
# Pose classified as cycling. Using weights: {'LEFT_SHOULDER': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_ELBOW': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_WRIST': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_HIP': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_KNEE': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_ANKLE': {'mediapipe': 0.3, 'rcnn': 0.7}}
# LEFT_SHOULDER - MediaPipe Consistency: 1.00, R-CNN Consistency: 1.00
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.98, R-CNN Consistency: 0.99
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 1.00, R-CNN Consistency: 1.00
# LEFT_HIP: Using R-CNN prediction.
# LEFT_KNEE - MediaPipe Consistency: 0.95, R-CNN Consistency: 1.00
# LEFT_KNEE: Using R-CNN prediction.
# LEFT_ANKLE - MediaPipe Consistency: 0.96, R-CNN Consistency: 0.99
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.52071, y=0.22093, confidence=1.00)
# LEFT_ELBOW: (x=0.48363, y=0.31223, confidence=1.00)
# LEFT_WRIST: (x=0.43614, y=0.37015, confidence=1.00)
# LEFT_HIP: (x=0.56487, y=0.36882, confidence=1.00)
# LEFT_KNEE: (x=0.49078, y=0.47140, confidence=1.00)
# LEFT_ANKLE: (x=0.50724, y=0.64593, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\checkdataset_final_output_grok3\9.png
# Saved keypoint coordinates to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\checkdataset_keypoint_coordinates_.xlsx

# %% [markdown]
# #### same final code for video frames

# %%
import cv2
import mediapipe as mp
import torch
import torchvision
import numpy as np
import os
import pandas as pd
from torchvision.transforms import functional as F

# Initialize MediaPipe Pose
mp_pose = mp.solutions.pose
mp_drawing = mp.solutions.drawing_utils
SELECTED_LANDMARKS = {
    "LEFT_SHOULDER": mp_pose.PoseLandmark.LEFT_SHOULDER,
    "LEFT_ELBOW": mp_pose.PoseLandmark.LEFT_ELBOW,
    "LEFT_WRIST": mp_pose.PoseLandmark.LEFT_WRIST,
    "LEFT_HIP": mp_pose.PoseLandmark.LEFT_HIP,
    "LEFT_KNEE": mp_pose.PoseLandmark.LEFT_KNEE,
    "LEFT_ANKLE": mp_pose.PoseLandmark.LEFT_ANKLE,
}

# Initialize Keypoint R-CNN
model_rcnn = torchvision.models.detection.keypointrcnn_resnet50_fpn(pretrained=True)
model_rcnn.eval()
device = torch.device("cpu")
model_rcnn.to(device)
COCO_KEYPOINTS = {
    "LEFT_SHOULDER": 5,
    "LEFT_ELBOW": 7,
    "LEFT_WRIST": 9,
    "LEFT_HIP": 11,
    "LEFT_KNEE": 13,
    "LEFT_ANKLE": 15,
}

EDGES = [
    ("LEFT_SHOULDER", "LEFT_ELBOW"),
    ("LEFT_ELBOW", "LEFT_WRIST"),
    ("LEFT_SHOULDER", "LEFT_HIP"),
    ("LEFT_HIP", "LEFT_KNEE"),
    ("LEFT_KNEE", "LEFT_ANKLE"),
]

# Default weights (balanced for most keypoints)
KEYPOINT_WEIGHTS_DEFAULT = {
    "LEFT_SHOULDER": {"mediapipe": 0.4, "rcnn": 0.6},
    "LEFT_ELBOW": {"mediapipe": 0.5, "rcnn": 0.5},
    "LEFT_WRIST": {"mediapipe": 0.3, "rcnn": 0.7},
    "LEFT_HIP": {"mediapipe": 0.4, "rcnn": 0.6},
    "LEFT_KNEE": {"mediapipe": 0.5, "rcnn": 0.5},  # Balanced weights by default
    "LEFT_ANKLE": {"mediapipe": 0.3, "rcnn": 0.7},
}

# Weights for cycling posture (favor R-CNN for knee)
KEYPOINT_WEIGHTS_CYCLING = {
    "LEFT_SHOULDER": {"mediapipe": 0.4, "rcnn": 0.6},
    "LEFT_ELBOW": {"mediapipe": 0.5, "rcnn": 0.5},
    "LEFT_WRIST": {"mediapipe": 0.3, "rcnn": 0.7},
    "LEFT_HIP": {"mediapipe": 0.4, "rcnn": 0.6},
    "LEFT_KNEE": {"mediapipe": 0.3, "rcnn": 0.7},  # Favor R-CNN for knee in cycling
    "LEFT_ANKLE": {"mediapipe": 0.3, "rcnn": 0.7},
}

def get_mediapipe_keypoints(image_path):
    image = cv2.imread(image_path)
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    normalized_keypoints = {}
    
    with mp_pose.Pose(static_image_mode=True, min_detection_confidence=0.5) as pose:
        results = pose.process(image_rgb)
        if results.pose_landmarks:
            height, width, _ = image.shape
            for name, landmark_enum in SELECTED_LANDMARKS.items():
                landmark = results.pose_landmarks.landmark[landmark_enum]
                normalized_keypoints[name] = (landmark.x, landmark.y, landmark.visibility)
    return normalized_keypoints

def get_rcnn_keypoints(image_path):
    image = cv2.imread(image_path)
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image_tensor = F.to_tensor(image_rgb).unsqueeze(0).to(device)
    
    with torch.no_grad():
        outputs = model_rcnn(image_tensor)
    keypoints = outputs[0]["keypoints"].cpu().numpy()
    scores = outputs[0]["scores"].cpu().numpy()
    keypoints = keypoints[scores > 0.5]
    
    if keypoints.shape[0] == 0:
        return {}
    
    height, width = image.shape[:2]
    selected_keypoints = {}
    for name, index in COCO_KEYPOINTS.items():
        x, y, conf = keypoints[0][index]
        x_normalized = x / width
        y_normalized = y / height
        selected_keypoints[name] = (x_normalized, y_normalized, conf)
    return selected_keypoints

def compute_distance(p1, p2):
    return np.sqrt((p1[0] - p2[0])**2 + (p1[1] - p2[1])**2)

def compute_angle(p1, p2, p3):
    v1 = np.array([p1[0] - p2[0], p1[1] - p2[1]])
    v2 = np.array([p3[0] - p2[0], p3[1] - p2[1]])
    cos_angle = np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2) + 1e-6)
    cos_angle = np.clip(cos_angle, -1.0, 1.0)
    return np.degrees(np.arccos(cos_angle))

def is_cycling_pose(keypoints):
    """Determine if the pose is likely a cycling posture."""
    if ("LEFT_SHOULDER" in keypoints and "LEFT_HIP" in keypoints and 
        "LEFT_KNEE" in keypoints and "LEFT_ANKLE" in keypoints):
        shoulder_y = keypoints["LEFT_SHOULDER"][1]
        hip_y = keypoints["LEFT_HIP"][1]
        knee_y = keypoints["LEFT_KNEE"][1]
        ankle_y = keypoints["LEFT_ANKLE"][1]
        shoulder_conf = keypoints["LEFT_SHOULDER"][2]
        hip_conf = keypoints["LEFT_HIP"][2]
        knee_conf = keypoints["LEFT_KNEE"][2]
        ankle_conf = keypoints["LEFT_ANKLE"][2]
        
        if shoulder_conf > 0.6 and hip_conf > 0.6 and knee_conf > 0.6 and ankle_conf > 0.6:
            # Check if torso is leaning forward (shoulder above hip but not too far)
            torso_lean = abs(shoulder_y - hip_y)
            # Check knee position relative to hip and ankle
            knee_angle = compute_angle(
                (keypoints["LEFT_HIP"][0], keypoints["LEFT_HIP"][1]),
                (keypoints["LEFT_KNEE"][0], keypoints["LEFT_KNEE"][1]),
                (keypoints["LEFT_ANKLE"][0], keypoints["LEFT_ANKLE"][1])
            )
            # Cycling posture: torso leaning forward, knee bent (angle typically 30°-150°)
            if torso_lean < 0.3 and 30 < knee_angle < 150:
                return True
    return False

def check_anatomical_violation(key, x, y, keypoints):
    penalty = 0.0
    
    if key == "LEFT_WRIST" and "LEFT_SHOULDER" in keypoints and keypoints["LEFT_SHOULDER"][2] > 0.6:
        shoulder_y = keypoints["LEFT_SHOULDER"][1]
        if y < shoulder_y - 0.05:
            penalty += 0.3
    
    if key == "LEFT_KNEE" and "LEFT_HIP" in keypoints and "LEFT_ANKLE" in keypoints:
        hip_y = keypoints["LEFT_HIP"][1]
        ankle_y = keypoints["LEFT_ANKLE"][1]
        hip_conf = keypoints["LEFT_HIP"][2]
        ankle_conf = keypoints["LEFT_ANKLE"][2]
        
        # Basic constraint: knee should not be above hip (relaxed for cycling)
        if y < hip_y - 0.05 and hip_conf > 0.6:
            penalty += 0.2  # Reduced penalty to allow for bent poses
        
        # Soft angle constraint: penalize extreme angles but don't enforce strictly
        if hip_conf > 0.6 and ankle_conf > 0.6:
            hip_x, hip_y, _ = keypoints["LEFT_HIP"]
            ankle_x, ankle_y, _ = keypoints["LEFT_ANKLE"]
            angle = compute_angle((hip_x, hip_y), (x, y), (ankle_x, ankle_y))
            if angle < 20 or angle > 170:  # Very extreme angles are unlikely
                penalty += 0.2
                print(f"Knee angle warning: {angle:.2f} degrees (extreme angle detected).")
    
    if key == "LEFT_ANKLE" and "LEFT_KNEE" in keypoints and keypoints["LEFT_KNEE"][2] > 0.6:
        knee_y = keypoints["LEFT_KNEE"][1]
        if y < knee_y - 0.05:
            penalty += 0.3
    
    if key == "LEFT_SHOULDER" and "LEFT_HIP" in keypoints and keypoints["LEFT_HIP"][2] > 0.6:
        hip_y = keypoints["LEFT_HIP"][1]
        if y > hip_y + 0.05:
            penalty += 0.3
    
    return penalty

def evaluate_keypoint_consistency(key, keypoints, other_keypoints, edges):
    x, y, conf = keypoints[key]
    if conf <= 0.5:  # Stricter threshold for consistency evaluation
        return 0.0
    
    neighbors = []
    for k1, k2 in edges:
        if k1 == key and k2 in keypoints and keypoints[k2][2] > 0.5:
            neighbors.append(k2)
        elif k2 == key and k1 in keypoints and keypoints[k1][2] > 0.5:
            neighbors.append(k1)
    
    if not neighbors:
        return conf * (1.0 - check_anatomical_violation(key, x, y, keypoints))
    
    consistency_score = 0.0
    count = 0
    for neighbor in neighbors:
        if neighbor in other_keypoints and other_keypoints[neighbor][2] > 0.5:
            my_x, my_y, _ = keypoints[key]
            my_neighbor_x, my_neighbor_y, _ = keypoints[neighbor]
            other_x, other_y, _ = other_keypoints[key]
            other_neighbor_x, other_neighbor_y, _ = other_keypoints[neighbor]
            
            my_dx = my_x - my_neighbor_x
            my_dy = my_y - my_neighbor_y
            other_dx = other_x - other_neighbor_x
            other_dy = other_y - other_neighbor_y
            
            my_dist = compute_distance((my_x, my_y), (my_neighbor_x, my_neighbor_y)) + 1e-6
            other_dist = compute_distance((other_x, other_y), (other_neighbor_x, other_neighbor_y)) + 1e-6
            my_dx_norm = my_dx / my_dist
            my_dy_norm = my_dy / my_dist
            other_dx_norm = other_dx / other_dist
            other_dy_norm = other_dy / other_dist
            
            similarity = 1.0 - 0.5 * (abs(my_dx_norm - other_dx_norm) + abs(my_dy_norm - other_dy_norm))
            consistency_score += similarity
            count += 1
    
    if count > 0:
        consistency_score /= count
        anatomical_penalty = check_anatomical_violation(key, x, y, keypoints)
        consistency_score *= (1.0 - anatomical_penalty)
        return 0.3 * consistency_score + 0.7 * conf
    return conf * (1.0 - check_anatomical_violation(key, x, y, keypoints))

def fuse_keypoints_selective(mediapipe_kps, rcnn_kps, edges):
    # Determine if the pose is cycling-like (based on MediaPipe keypoints for simplicity)
    is_cycling = is_cycling_pose(mediapipe_kps)
    KEYPOINT_WEIGHTS = KEYPOINT_WEIGHTS_CYCLING if is_cycling else KEYPOINT_WEIGHTS_DEFAULT
    print(f"Pose classified as {'cycling' if is_cycling else 'non-cycling'}. Using weights: {KEYPOINT_WEIGHTS}")
    
    fused_keypoints = {}
    
    for key in SELECTED_LANDMARKS.keys():
        mp_kp = mediapipe_kps.get(key, (0.0, 0.0, 0.0))
        rcnn_kp = rcnn_kps.get(key, (0.0, 0.0, 0.0))
        
        mp_x, mp_y, mp_conf = mp_kp
        rcnn_x, rcnn_y, rcnn_conf = rcnn_kp
        
        mp_consistency = evaluate_keypoint_consistency(key, mediapipe_kps, rcnn_kps, edges) if mp_conf > 0 else 0.0
        rcnn_consistency = evaluate_keypoint_consistency(key, rcnn_kps, mediapipe_kps, edges) if rcnn_conf > 0 else 0.0
        
        print(f"{key} - MediaPipe Consistency: {mp_consistency:.2f}, R-CNN Consistency: {rcnn_consistency:.2f}")
        
        mp_weight = KEYPOINT_WEIGHTS[key]["mediapipe"]
        rcnn_weight = KEYPOINT_WEIGHTS[key]["rcnn"]
        mp_adjusted = mp_consistency * mp_weight
        rcnn_adjusted = rcnn_consistency * rcnn_weight
        
        if mp_adjusted > rcnn_adjusted + 0.1:
            fused_x, fused_y, fused_conf = mp_x, mp_y, mp_conf
            print(f"{key}: Using MediaPipe prediction.")
        elif rcnn_adjusted > mp_adjusted + 0.1:
            fused_x, fused_y, fused_conf = rcnn_x, rcnn_y, rcnn_conf
            print(f"{key}: Using R-CNN prediction.")
        elif mp_conf > 0 and rcnn_conf > 0:
            total_weight = mp_weight + rcnn_weight
            mp_fusion_weight = mp_weight / total_weight
            rcnn_fusion_weight = rcnn_weight / total_weight
            fused_x = mp_fusion_weight * mp_x + rcnn_fusion_weight * rcnn_x
            fused_y = mp_fusion_weight * mp_y + rcnn_fusion_weight * rcnn_y
            fused_conf = max(mp_conf, rcnn_conf)
            print(f"{key}: Using weighted averaging with weights (MP: {mp_fusion_weight:.2f}, R-CNN: {rcnn_fusion_weight:.2f}).")
        elif mp_conf > 0:
            fused_x, fused_y, fused_conf = mp_x, mp_y, mp_conf
            print(f"{key}: Using MediaPipe prediction (R-CNN unavailable).")
        elif rcnn_conf > 0:
            fused_x, fused_y, fused_conf = rcnn_x, rcnn_y, rcnn_conf
            print(f"{key}: Using R-CNN prediction (MediaPipe unavailable).")
        else:
            fused_x, fused_y, fused_conf = 0.0, 0.0, 0.0
            print(f"{key}: No reliable prediction available.")
        
        fused_keypoints[key] = (fused_x, fused_y, fused_conf)
    
    return fused_keypoints

def fallback_and_correct(fused_kps, mediapipe_kps, rcnn_kps, edges):
    adjusted_kps = fused_kps.copy()
    
    # Fallback for low-confidence keypoints
    for key in adjusted_kps.keys():
        x, y, conf = adjusted_kps[key]
        if conf <= 0.5:  # Stricter threshold for fallback
            neighbors = []
            for k1, k2 in edges:
                if k1 == key and k2 in adjusted_kps and adjusted_kps[k2][2] > 0.5:
                    neighbors.append((k2, adjusted_kps[k2]))
                elif k2 == key and k1 in adjusted_kps and adjusted_kps[k1][2] > 0.5:
                    neighbors.append((k1, adjusted_kps[k1]))
            
            if neighbors:
                total_conf = sum(n_conf for _, (_, _, n_conf) in neighbors)
                if total_conf > 0:
                    avg_x = sum(nx * n_conf for _, (nx, _, n_conf) in neighbors) / total_conf
                    avg_y = sum(ny * n_conf for _, (_, ny, n_conf) in neighbors) / total_conf
                    adjusted_kps[key] = (avg_x, avg_y, 0.5)
                    print(f"{key}: Estimated position using neighbors.")
    
    # Softer anatomical corrections
    if "LEFT_SHOULDER" in adjusted_kps and "LEFT_HIP" in adjusted_kps:
        shoulder_y = adjusted_kps["LEFT_SHOULDER"][1]
        hip_y = adjusted_kps["LEFT_HIP"][1]
        shoulder_conf = adjusted_kps["LEFT_SHOULDER"][2]
        hip_conf = adjusted_kps["LEFT_HIP"][2]
        if shoulder_y > hip_y + 0.05 and shoulder_conf > 0.6 and hip_conf > 0.6:
            adjusted_kps["LEFT_SHOULDER"] = (adjusted_kps["LEFT_SHOULDER"][0], hip_y - 0.05, shoulder_conf * 0.9)
            print("Corrected LEFT_SHOULDER position (was below hip).")
    
    if "LEFT_SHOULDER" in adjusted_kps and "LEFT_WRIST" in adjusted_kps:
        shoulder_y = adjusted_kps["LEFT_SHOULDER"][1]
        wrist_y = adjusted_kps["LEFT_WRIST"][1]
        wrist_conf = adjusted_kps["LEFT_WRIST"][2]
        if wrist_y < shoulder_y - 0.05 and wrist_conf > 0.6:
            adjusted_kps["LEFT_WRIST"] = (adjusted_kps["LEFT_WRIST"][0], shoulder_y, wrist_conf * 0.8)
            print("Corrected LEFT_WRIST position (was above shoulder).")
    
    if "LEFT_HIP" in adjusted_kps and "LEFT_KNEE" in adjusted_kps:
        hip_y = adjusted_kps["LEFT_HIP"][1]
        knee_y = adjusted_kps["LEFT_KNEE"][1]
        knee_conf = adjusted_kps["LEFT_KNEE"][2]
        if knee_y < hip_y - 0.05 and knee_conf > 0.6:
            # Blend the original position with the corrected position
            corrected_y = hip_y - 0.02
            blended_y = 0.7 * knee_y + 0.3 * corrected_y  # Soft correction
            adjusted_kps["LEFT_KNEE"] = (adjusted_kps["LEFT_KNEE"][0], blended_y, knee_conf * 0.9)
            print("Soft-corrected LEFT_KNEE position (was too far above hip).")
    
    if "LEFT_KNEE" in adjusted_kps and "LEFT_ANKLE" in adjusted_kps:
        knee_y = adjusted_kps["LEFT_KNEE"][1]
        ankle_y = adjusted_kps["LEFT_ANKLE"][1]
        ankle_conf = adjusted_kps["LEFT_ANKLE"][2]
        if ankle_y < knee_y - 0.05 and ankle_conf > 0.6:
            corrected_y = knee_y + 0.02
            blended_y = 0.7 * ankle_y + 0.3 * corrected_y
            adjusted_kps["LEFT_ANKLE"] = (adjusted_kps["LEFT_ANKLE"][0], blended_y, ankle_conf * 0.8)
            print("Soft-corrected LEFT_ANKLE position (was too far above knee).")
    
    return adjusted_kps

def draw_fused_keypoints(image, keypoints):
    height, width = image.shape[:2]
    for name, (x_norm, y_norm, conf) in keypoints.items():
        if conf > 0.5:  # Relaxed threshold for visualization
            x_pixel, y_pixel = int(x_norm * width), int(y_norm * height)
            cv2.circle(image, (x_pixel, y_pixel), 5, (255, 0, 0), -1)
            coord_text = f"{name}: ({x_norm:.5f}, {y_norm:.5f})"
            cv2.putText(image, coord_text, (x_pixel + 10, y_pixel - 10), 
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 1)
    return image

def process_dataset(input_folder, output_folder, excel_path):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    data = []
    image_files = [f for f in os.listdir(input_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]
    
    for image_file in image_files:
        print(f"\nProcessing {image_file}...")
        image_path = os.path.join(input_folder, image_file)
        
        try:
            image_no = int(os.path.splitext(image_file)[0])
        except ValueError:
            print(f"Could not extract image number from {image_file}, skipping...")
            continue
        
        image = cv2.imread(image_path)
        if image is None:
            print(f"Failed to load image: {image_path}")
            continue
        
        mediapipe_kps = get_mediapipe_keypoints(image_path)
        rcnn_kps = get_rcnn_keypoints(image_path)
        
        print("\nMediaPipe Keypoints:")
        for name, (x, y, conf) in mediapipe_kps.items():
            print(f"{name}: (x={x:.5f}, y={y:.5f}, confidence={conf:.2f})")
        print("\nR-CNN Keypoints:")
        for name, (x, y, conf) in rcnn_kps.items():
            print(f"{name}: (x={x:.5f}, y={y:.5f}, confidence={conf:.2f})")
        
        fused_keypoints = fuse_keypoints_selective(mediapipe_kps, rcnn_kps, EDGES)
        fused_keypoints = fallback_and_correct(fused_keypoints, mediapipe_kps, rcnn_kps, EDGES)
        
        print("\nFused Keypoints:")
        for name, (x, y, conf) in fused_keypoints.items():
            print(f"{name}: (x={x:.5f}, y={y:.5f}, confidence={conf:.2f})")
        
        row = {
            "image_no": image_no,
            "left_shoulder_x": round(fused_keypoints["LEFT_SHOULDER"][0], 5),
            "left_shoulder_y": round(fused_keypoints["LEFT_SHOULDER"][1], 5),
            "left_elbow_x": round(fused_keypoints["LEFT_ELBOW"][0], 5),
            "left_elbow_y": round(fused_keypoints["LEFT_ELBOW"][1], 5),
            "left_wrist_x": round(fused_keypoints["LEFT_WRIST"][0], 5),
            "left_wrist_y": round(fused_keypoints["LEFT_WRIST"][1], 5),
            "left_hip_x": round(fused_keypoints["LEFT_HIP"][0], 5),
            "left_hip_y": round(fused_keypoints["LEFT_HIP"][1], 5),
            "left_knee_x": round(fused_keypoints["LEFT_KNEE"][0], 5),
            "left_knee_y": round(fused_keypoints["LEFT_KNEE"][1], 5),
            "left_ankle_x": round(fused_keypoints["LEFT_ANKLE"][0], 5),
            "left_ankle_y": round(fused_keypoints["LEFT_ANKLE"][1], 5),
        }
        data.append(row)
        
        output_image = draw_fused_keypoints(image.copy(), fused_keypoints)
        output_path = os.path.join(output_folder, image_file)
        cv2.imwrite(output_path, output_image)
        print(f"Saved annotated image to {output_path}")
    
    df = pd.DataFrame(data)
    df = df.sort_values(by="image_no")
    df.to_excel(excel_path, index=False)
    print(f"Saved keypoint coordinates to {excel_path}")

# Define input and output folders, and Excel file path
input_folder = r"C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\CHECK DATASET\checkdataset"
output_folder = r"C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\CHECK DATASET\checkdataset_output_2video"
excel_path = r"C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\CHECK DATASET\checkdataset_2video_coordinates.xlsx"

# Process the dataset and generate Excel file
process_dataset(input_folder, output_folder, excel_path)
# Out:
# c:\Users\Habeeba\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\Habeeba\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=KeypointRCNN_ResNet50_FPN_Weights.COCO_V1`. You can also use `weights=KeypointRCNN_ResNet50_FPN_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Processing 1.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.47125, y=0.27856, confidence=1.00)
# LEFT_ELBOW: (x=0.46738, y=0.38139, confidence=0.96)
# LEFT_WRIST: (x=0.41266, y=0.36985, confidence=0.98)
# LEFT_HIP: (x=0.56324, y=0.37135, confidence=1.00)
# LEFT_KNEE: (x=0.48337, y=0.43926, confidence=0.98)
# LEFT_ANKLE: (x=0.54677, y=0.54341, confidence=0.95)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.47109, y=0.27152, confidence=1.00)
# LEFT_ELBOW: (x=0.46510, y=0.38354, confidence=1.00)
# LEFT_WRIST: (x=0.41121, y=0.36487, confidence=1.00)
# LEFT_HIP: (x=0.56167, y=0.36487, confidence=1.00)
# LEFT_KNEE: (x=0.48307, y=0.43688, confidence=1.00)
# LEFT_ANKLE: (x=0.54819, y=0.54357, confidence=1.00)
# Pose classified as cycling. Using weights: {'LEFT_SHOULDER': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_ELBOW': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_WRIST': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_HIP': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_KNEE': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_ANKLE': {'mediapipe': 0.3, 'rcnn': 0.7}}
# LEFT_SHOULDER - MediaPipe Consistency: 1.00, R-CNN Consistency: 1.00
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.96, R-CNN Consistency: 0.99
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.96, R-CNN Consistency: 0.98
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_HIP: Using R-CNN prediction.
# LEFT_KNEE - MediaPipe Consistency: 0.98, R-CNN Consistency: 1.00
# LEFT_KNEE: Using R-CNN prediction.
# LEFT_ANKLE - MediaPipe Consistency: 0.96, R-CNN Consistency: 1.00
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.47109, y=0.27152, confidence=1.00)
# LEFT_ELBOW: (x=0.46624, y=0.38247, confidence=1.00)
# LEFT_WRIST: (x=0.41121, y=0.36487, confidence=1.00)
# LEFT_HIP: (x=0.56167, y=0.36487, confidence=1.00)
# LEFT_KNEE: (x=0.48307, y=0.43688, confidence=1.00)
# LEFT_ANKLE: (x=0.54819, y=0.54357, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\CHECK DATASET\checkdataset_output_2video\1.png
#
# Processing 10.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.52190, y=0.25720, confidence=1.00)
# LEFT_ELBOW: (x=0.48761, y=0.33519, confidence=0.99)
# LEFT_WRIST: (x=0.44323, y=0.38391, confidence=0.98)
# LEFT_HIP: (x=0.56888, y=0.41095, confidence=1.00)
# LEFT_KNEE: (x=0.53195, y=0.53234, confidence=0.98)
# LEFT_ANKLE: (x=0.57963, y=0.64543, confidence=0.98)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.52950, y=0.25055, confidence=1.00)
# LEFT_ELBOW: (x=0.49066, y=0.33056, confidence=1.00)
# LEFT_WRIST: (x=0.44209, y=0.38524, confidence=1.00)
# LEFT_HIP: (x=0.57134, y=0.39590, confidence=1.00)
# LEFT_KNEE: (x=0.50186, y=0.46924, confidence=1.00)
# LEFT_ANKLE: (x=0.57806, y=0.64926, confidence=1.00)
# Pose classified as cycling. Using weights: {'LEFT_SHOULDER': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_ELBOW': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_WRIST': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_HIP': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_KNEE': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_ANKLE': {'mediapipe': 0.3, 'rcnn': 0.7}}
# LEFT_SHOULDER - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.98, R-CNN Consistency: 1.00
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 0.95, R-CNN Consistency: 0.95
# LEFT_HIP: Using R-CNN prediction.
# LEFT_KNEE - MediaPipe Consistency: 0.94, R-CNN Consistency: 0.95
# LEFT_KNEE: Using R-CNN prediction.
# LEFT_ANKLE - MediaPipe Consistency: 0.99, R-CNN Consistency: 1.00
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.52950, y=0.25055, confidence=1.00)
# LEFT_ELBOW: (x=0.48913, y=0.33287, confidence=1.00)
# LEFT_WRIST: (x=0.44209, y=0.38524, confidence=1.00)
# LEFT_HIP: (x=0.57134, y=0.39590, confidence=1.00)
# LEFT_KNEE: (x=0.50186, y=0.46924, confidence=1.00)
# LEFT_ANKLE: (x=0.57806, y=0.64926, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\CHECK DATASET\checkdataset_output_2video\10.png
#
# Processing 100.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.54052, y=0.23793, confidence=1.00)
# LEFT_ELBOW: (x=0.49820, y=0.35152, confidence=1.00)
# LEFT_WRIST: (x=0.44145, y=0.41025, confidence=0.99)
# LEFT_HIP: (x=0.59055, y=0.42443, confidence=1.00)
# LEFT_KNEE: (x=0.50519, y=0.53129, confidence=0.99)
# LEFT_ANKLE: (x=0.56843, y=0.68445, confidence=0.98)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.54958, y=0.22311, confidence=1.00)
# LEFT_ELBOW: (x=0.49640, y=0.34170, confidence=1.00)
# LEFT_WRIST: (x=0.43723, y=0.41366, confidence=1.00)
# LEFT_HIP: (x=0.59751, y=0.41499, confidence=1.00)
# LEFT_KNEE: (x=0.50913, y=0.54425, confidence=1.00)
# LEFT_ANKLE: (x=0.58553, y=0.69615, confidence=1.00)
# Pose classified as cycling. Using weights: {'LEFT_SHOULDER': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_ELBOW': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_WRIST': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_HIP': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_KNEE': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_ANKLE': {'mediapipe': 0.3, 'rcnn': 0.7}}
# LEFT_SHOULDER - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.98, R-CNN Consistency: 0.99
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.97, R-CNN Consistency: 0.98
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_HIP: Using R-CNN prediction.
# LEFT_KNEE - MediaPipe Consistency: 0.98, R-CNN Consistency: 0.98
# LEFT_KNEE: Using R-CNN prediction.
# LEFT_ANKLE - MediaPipe Consistency: 0.97, R-CNN Consistency: 0.99
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.54958, y=0.22311, confidence=1.00)
# LEFT_ELBOW: (x=0.49730, y=0.34661, confidence=1.00)
# LEFT_WRIST: (x=0.43723, y=0.41366, confidence=1.00)
# LEFT_HIP: (x=0.59751, y=0.41499, confidence=1.00)
# LEFT_KNEE: (x=0.50913, y=0.54425, confidence=1.00)
# LEFT_ANKLE: (x=0.58553, y=0.69615, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\CHECK DATASET\checkdataset_output_2video\100.png
#
# Processing 101.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.54426, y=0.23204, confidence=1.00)
# LEFT_ELBOW: (x=0.50443, y=0.34486, confidence=0.98)
# LEFT_WRIST: (x=0.44185, y=0.40566, confidence=0.97)
# LEFT_HIP: (x=0.59057, y=0.41537, confidence=1.00)
# LEFT_KNEE: (x=0.50626, y=0.52354, confidence=0.98)
# LEFT_ANKLE: (x=0.57292, y=0.65598, confidence=0.97)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.54916, y=0.22343, confidence=1.00)
# LEFT_ELBOW: (x=0.49678, y=0.33803, confidence=1.00)
# LEFT_WRIST: (x=0.43543, y=0.41132, confidence=1.00)
# LEFT_HIP: (x=0.59554, y=0.42198, confidence=1.00)
# LEFT_KNEE: (x=0.50501, y=0.52592, confidence=1.00)
# LEFT_ANKLE: (x=0.58283, y=0.66184, confidence=1.00)
# Pose classified as cycling. Using weights: {'LEFT_SHOULDER': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_ELBOW': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_WRIST': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_HIP': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_KNEE': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_ANKLE': {'mediapipe': 0.3, 'rcnn': 0.7}}
# LEFT_SHOULDER - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.97, R-CNN Consistency: 0.98
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.96, R-CNN Consistency: 0.98
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_HIP: Using R-CNN prediction.
# LEFT_KNEE - MediaPipe Consistency: 0.98, R-CNN Consistency: 0.99
# LEFT_KNEE: Using R-CNN prediction.
# LEFT_ANKLE - MediaPipe Consistency: 0.97, R-CNN Consistency: 0.99
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.54916, y=0.22343, confidence=1.00)
# LEFT_ELBOW: (x=0.50060, y=0.34144, confidence=1.00)
# LEFT_WRIST: (x=0.43543, y=0.41132, confidence=1.00)
# LEFT_HIP: (x=0.59554, y=0.42198, confidence=1.00)
# LEFT_KNEE: (x=0.50501, y=0.52592, confidence=1.00)
# LEFT_ANKLE: (x=0.58283, y=0.66184, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\CHECK DATASET\checkdataset_output_2video\101.png
#
# Processing 102.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.54336, y=0.23503, confidence=1.00)
# LEFT_ELBOW: (x=0.50412, y=0.34730, confidence=0.99)
# LEFT_WRIST: (x=0.44170, y=0.40614, confidence=0.99)
# LEFT_HIP: (x=0.58722, y=0.41654, confidence=1.00)
# LEFT_KNEE: (x=0.49448, y=0.49786, confidence=0.99)
# LEFT_ANKLE: (x=0.56429, y=0.60884, confidence=0.97)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.54830, y=0.22535, confidence=1.00)
# LEFT_ELBOW: (x=0.49593, y=0.33994, confidence=1.00)
# LEFT_WRIST: (x=0.43459, y=0.41190, confidence=1.00)
# LEFT_HIP: (x=0.59394, y=0.42256, confidence=1.00)
# LEFT_KNEE: (x=0.50042, y=0.50251, confidence=1.00)
# LEFT_ANKLE: (x=0.57748, y=0.62643, confidence=1.00)
# Pose classified as cycling. Using weights: {'LEFT_SHOULDER': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_ELBOW': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_WRIST': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_HIP': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_KNEE': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_ANKLE': {'mediapipe': 0.3, 'rcnn': 0.7}}
# LEFT_SHOULDER - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.97, R-CNN Consistency: 0.98
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.97, R-CNN Consistency: 0.98
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 1.00, R-CNN Consistency: 1.00
# LEFT_HIP: Using R-CNN prediction.
# LEFT_KNEE - MediaPipe Consistency: 0.99, R-CNN Consistency: 1.00
# LEFT_KNEE: Using R-CNN prediction.
# LEFT_ANKLE - MediaPipe Consistency: 0.97, R-CNN Consistency: 1.00
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.54830, y=0.22535, confidence=1.00)
# LEFT_ELBOW: (x=0.50003, y=0.34362, confidence=1.00)
# LEFT_WRIST: (x=0.43459, y=0.41190, confidence=1.00)
# LEFT_HIP: (x=0.59394, y=0.42256, confidence=1.00)
# LEFT_KNEE: (x=0.50042, y=0.50251, confidence=1.00)
# LEFT_ANKLE: (x=0.57748, y=0.62643, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\CHECK DATASET\checkdataset_output_2video\102.png
#
# Processing 103.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.54391, y=0.23221, confidence=1.00)
# LEFT_ELBOW: (x=0.50477, y=0.33811, confidence=0.99)
# LEFT_WRIST: (x=0.44235, y=0.40315, confidence=0.98)
# LEFT_HIP: (x=0.59376, y=0.41759, confidence=1.00)
# LEFT_KNEE: (x=0.49136, y=0.47235, confidence=0.96)
# LEFT_ANKLE: (x=0.56289, y=0.59040, confidence=0.92)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.54835, y=0.22445, confidence=1.00)
# LEFT_ELBOW: (x=0.49584, y=0.33923, confidence=1.00)
# LEFT_WRIST: (x=0.43433, y=0.41798, confidence=1.00)
# LEFT_HIP: (x=0.59410, y=0.42065, confidence=1.00)
# LEFT_KNEE: (x=0.49584, y=0.47537, confidence=1.00)
# LEFT_ANKLE: (x=0.57385, y=0.61285, confidence=1.00)
# Pose classified as cycling. Using weights: {'LEFT_SHOULDER': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_ELBOW': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_WRIST': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_HIP': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_KNEE': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_ANKLE': {'mediapipe': 0.3, 'rcnn': 0.7}}
# LEFT_SHOULDER - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.97, R-CNN Consistency: 0.98
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.97, R-CNN Consistency: 0.98
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 0.99, R-CNN Consistency: 1.00
# LEFT_HIP: Using R-CNN prediction.
# LEFT_KNEE - MediaPipe Consistency: 0.97, R-CNN Consistency: 1.00
# LEFT_KNEE: Using R-CNN prediction.
# LEFT_ANKLE - MediaPipe Consistency: 0.94, R-CNN Consistency: 0.99
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.54835, y=0.22445, confidence=1.00)
# LEFT_ELBOW: (x=0.50030, y=0.33867, confidence=1.00)
# LEFT_WRIST: (x=0.43433, y=0.41798, confidence=1.00)
# LEFT_HIP: (x=0.59410, y=0.42065, confidence=1.00)
# LEFT_KNEE: (x=0.49584, y=0.47537, confidence=1.00)
# LEFT_ANKLE: (x=0.57385, y=0.61285, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\CHECK DATASET\checkdataset_output_2video\103.png
#
# Processing 104.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.54205, y=0.23141, confidence=1.00)
# LEFT_ELBOW: (x=0.50232, y=0.34062, confidence=0.98)
# LEFT_WRIST: (x=0.44054, y=0.40179, confidence=0.98)
# LEFT_HIP: (x=0.59399, y=0.41243, confidence=1.00)
# LEFT_KNEE: (x=0.48969, y=0.45847, confidence=0.96)
# LEFT_ANKLE: (x=0.54786, y=0.58569, confidence=0.94)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.54863, y=0.22483, confidence=1.00)
# LEFT_ELBOW: (x=0.49539, y=0.34091, confidence=1.00)
# LEFT_WRIST: (x=0.43465, y=0.41563, confidence=1.00)
# LEFT_HIP: (x=0.59212, y=0.41830, confidence=1.00)
# LEFT_KNEE: (x=0.49089, y=0.45700, confidence=1.00)
# LEFT_ANKLE: (x=0.55837, y=0.60377, confidence=1.00)
# Pose classified as cycling. Using weights: {'LEFT_SHOULDER': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_ELBOW': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_WRIST': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_HIP': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_KNEE': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_ANKLE': {'mediapipe': 0.3, 'rcnn': 0.7}}
# LEFT_SHOULDER - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.96, R-CNN Consistency: 0.98
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.96, R-CNN Consistency: 0.98
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_HIP: Using R-CNN prediction.
# LEFT_KNEE - MediaPipe Consistency: 0.97, R-CNN Consistency: 0.99
# LEFT_KNEE: Using R-CNN prediction.
# LEFT_ANKLE - MediaPipe Consistency: 0.96, R-CNN Consistency: 1.00
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.54863, y=0.22483, confidence=1.00)
# LEFT_ELBOW: (x=0.49885, y=0.34076, confidence=1.00)
# LEFT_WRIST: (x=0.43465, y=0.41563, confidence=1.00)
# LEFT_HIP: (x=0.59212, y=0.41830, confidence=1.00)
# LEFT_KNEE: (x=0.49089, y=0.45700, confidence=1.00)
# LEFT_ANKLE: (x=0.55837, y=0.60377, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\CHECK DATASET\checkdataset_output_2video\104.png
#
# Processing 105.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.53864, y=0.23660, confidence=1.00)
# LEFT_ELBOW: (x=0.49968, y=0.34060, confidence=0.96)
# LEFT_WRIST: (x=0.43811, y=0.41020, confidence=0.96)
# LEFT_HIP: (x=0.59124, y=0.40343, confidence=1.00)
# LEFT_KNEE: (x=0.48672, y=0.45884, confidence=0.96)
# LEFT_ANKLE: (x=0.53924, y=0.60450, confidence=0.93)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.54861, y=0.22305, confidence=1.00)
# LEFT_ELBOW: (x=0.49697, y=0.34167, confidence=1.00)
# LEFT_WRIST: (x=0.43560, y=0.41897, confidence=1.00)
# LEFT_HIP: (x=0.59651, y=0.41097, confidence=1.00)
# LEFT_KNEE: (x=0.49248, y=0.45495, confidence=1.00)
# LEFT_ANKLE: (x=0.54412, y=0.63220, confidence=1.00)
# Pose classified as cycling. Using weights: {'LEFT_SHOULDER': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_ELBOW': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_WRIST': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_HIP': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_KNEE': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_ANKLE': {'mediapipe': 0.3, 'rcnn': 0.7}}
# LEFT_SHOULDER - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.96, R-CNN Consistency: 0.99
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.96, R-CNN Consistency: 0.99
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 0.98, R-CNN Consistency: 0.99
# LEFT_HIP: Using R-CNN prediction.
# LEFT_KNEE - MediaPipe Consistency: 0.96, R-CNN Consistency: 0.99
# LEFT_KNEE: Using R-CNN prediction.
# LEFT_ANKLE - MediaPipe Consistency: 0.94, R-CNN Consistency: 0.99
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.54861, y=0.22305, confidence=1.00)
# LEFT_ELBOW: (x=0.49833, y=0.34113, confidence=1.00)
# LEFT_WRIST: (x=0.43560, y=0.41897, confidence=1.00)
# LEFT_HIP: (x=0.59651, y=0.41097, confidence=1.00)
# LEFT_KNEE: (x=0.49248, y=0.45495, confidence=1.00)
# LEFT_ANKLE: (x=0.54412, y=0.63220, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\CHECK DATASET\checkdataset_output_2video\105.png
#
# Processing 106.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.53988, y=0.23516, confidence=1.00)
# LEFT_ELBOW: (x=0.50232, y=0.34504, confidence=0.96)
# LEFT_WRIST: (x=0.43838, y=0.40908, confidence=0.96)
# LEFT_HIP: (x=0.59229, y=0.40365, confidence=1.00)
# LEFT_KNEE: (x=0.49540, y=0.47062, confidence=0.94)
# LEFT_ANKLE: (x=0.53216, y=0.63616, confidence=0.91)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.54792, y=0.22176, confidence=1.00)
# LEFT_ELBOW: (x=0.49925, y=0.33654, confidence=1.00)
# LEFT_WRIST: (x=0.43785, y=0.42063, confidence=1.00)
# LEFT_HIP: (x=0.59584, y=0.41262, confidence=1.00)
# LEFT_KNEE: (x=0.49251, y=0.46334, confidence=1.00)
# LEFT_ANKLE: (x=0.53669, y=0.64353, confidence=1.00)
# Pose classified as cycling. Using weights: {'LEFT_SHOULDER': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_ELBOW': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_WRIST': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_HIP': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_KNEE': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_ANKLE': {'mediapipe': 0.3, 'rcnn': 0.7}}
# LEFT_SHOULDER - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.95, R-CNN Consistency: 0.98
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.94, R-CNN Consistency: 0.97
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 0.98, R-CNN Consistency: 0.98
# LEFT_HIP: Using R-CNN prediction.
# LEFT_KNEE - MediaPipe Consistency: 0.94, R-CNN Consistency: 0.98
# LEFT_KNEE: Using R-CNN prediction.
# LEFT_ANKLE - MediaPipe Consistency: 0.93, R-CNN Consistency: 1.00
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.54792, y=0.22176, confidence=1.00)
# LEFT_ELBOW: (x=0.50078, y=0.34079, confidence=1.00)
# LEFT_WRIST: (x=0.43785, y=0.42063, confidence=1.00)
# LEFT_HIP: (x=0.59584, y=0.41262, confidence=1.00)
# LEFT_KNEE: (x=0.49251, y=0.46334, confidence=1.00)
# LEFT_ANKLE: (x=0.53669, y=0.64353, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\CHECK DATASET\checkdataset_output_2video\106.png
#
# Processing 107.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.54264, y=0.23001, confidence=1.00)
# LEFT_ELBOW: (x=0.50941, y=0.33999, confidence=0.96)
# LEFT_WRIST: (x=0.44517, y=0.40047, confidence=0.97)
# LEFT_HIP: (x=0.59425, y=0.41337, confidence=1.00)
# LEFT_KNEE: (x=0.49519, y=0.48516, confidence=0.92)
# LEFT_ANKLE: (x=0.52763, y=0.67945, confidence=0.87)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.54810, y=0.22168, confidence=1.00)
# LEFT_ELBOW: (x=0.49861, y=0.34043, confidence=1.00)
# LEFT_WRIST: (x=0.43712, y=0.41516, confidence=1.00)
# LEFT_HIP: (x=0.59834, y=0.41783, confidence=1.00)
# LEFT_KNEE: (x=0.49636, y=0.48988, confidence=1.00)
# LEFT_ANKLE: (x=0.52185, y=0.68469, confidence=1.00)
# Pose classified as cycling. Using weights: {'LEFT_SHOULDER': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_ELBOW': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_WRIST': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_HIP': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_KNEE': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_ANKLE': {'mediapipe': 0.3, 'rcnn': 0.7}}
# LEFT_SHOULDER - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.95, R-CNN Consistency: 0.98
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.95, R-CNN Consistency: 0.97
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 0.99, R-CNN Consistency: 1.00
# LEFT_HIP: Using R-CNN prediction.
# LEFT_KNEE - MediaPipe Consistency: 0.94, R-CNN Consistency: 1.00
# LEFT_KNEE: Using R-CNN prediction.
# LEFT_ANKLE - MediaPipe Consistency: 0.91, R-CNN Consistency: 0.99
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.54810, y=0.22168, confidence=1.00)
# LEFT_ELBOW: (x=0.50401, y=0.34021, confidence=1.00)
# LEFT_WRIST: (x=0.43712, y=0.41516, confidence=1.00)
# LEFT_HIP: (x=0.59834, y=0.41783, confidence=1.00)
# LEFT_KNEE: (x=0.49636, y=0.48988, confidence=1.00)
# LEFT_ANKLE: (x=0.52185, y=0.68469, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\CHECK DATASET\checkdataset_output_2video\107.png
#
# Processing 108.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.54273, y=0.23073, confidence=1.00)
# LEFT_ELBOW: (x=0.50687, y=0.34501, confidence=0.98)
# LEFT_WRIST: (x=0.44644, y=0.40157, confidence=0.98)
# LEFT_HIP: (x=0.59405, y=0.41917, confidence=1.00)
# LEFT_KNEE: (x=0.50735, y=0.51854, confidence=0.96)
# LEFT_ANKLE: (x=0.53074, y=0.70805, confidence=0.95)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.54864, y=0.22290, confidence=1.00)
# LEFT_ELBOW: (x=0.49847, y=0.34025, confidence=1.00)
# LEFT_WRIST: (x=0.43632, y=0.41626, confidence=1.00)
# LEFT_HIP: (x=0.60105, y=0.42293, confidence=1.00)
# LEFT_KNEE: (x=0.50221, y=0.52294, confidence=1.00)
# LEFT_ANKLE: (x=0.52767, y=0.73364, confidence=1.00)
# Pose classified as cycling. Using weights: {'LEFT_SHOULDER': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_ELBOW': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_WRIST': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_HIP': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_KNEE': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_ANKLE': {'mediapipe': 0.3, 'rcnn': 0.7}}
# LEFT_SHOULDER - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.96, R-CNN Consistency: 0.98
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.96, R-CNN Consistency: 0.97
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_HIP: Using R-CNN prediction.
# LEFT_KNEE - MediaPipe Consistency: 0.96, R-CNN Consistency: 0.99
# LEFT_KNEE: Using R-CNN prediction.
# LEFT_ANKLE - MediaPipe Consistency: 0.96, R-CNN Consistency: 1.00
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.54864, y=0.22290, confidence=1.00)
# LEFT_ELBOW: (x=0.50267, y=0.34263, confidence=1.00)
# LEFT_WRIST: (x=0.43632, y=0.41626, confidence=1.00)
# LEFT_HIP: (x=0.60105, y=0.42293, confidence=1.00)
# LEFT_KNEE: (x=0.50221, y=0.52294, confidence=1.00)
# LEFT_ANKLE: (x=0.52767, y=0.73364, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\CHECK DATASET\checkdataset_output_2video\108.png
#
# Processing 109.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.54176, y=0.23910, confidence=1.00)
# LEFT_ELBOW: (x=0.50128, y=0.35447, confidence=0.98)
# LEFT_WRIST: (x=0.44091, y=0.40953, confidence=0.96)
# LEFT_HIP: (x=0.59557, y=0.42992, confidence=1.00)
# LEFT_KNEE: (x=0.51966, y=0.54764, confidence=0.95)
# LEFT_ANKLE: (x=0.53216, y=0.73407, confidence=0.97)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.54916, y=0.22157, confidence=1.00)
# LEFT_ELBOW: (x=0.49819, y=0.33903, confidence=1.00)
# LEFT_WRIST: (x=0.43748, y=0.41511, confidence=1.00)
# LEFT_HIP: (x=0.59938, y=0.42579, confidence=1.00)
# LEFT_KNEE: (x=0.51019, y=0.55259, confidence=1.00)
# LEFT_ANKLE: (x=0.53192, y=0.76481, confidence=1.00)
# Pose classified as cycling. Using weights: {'LEFT_SHOULDER': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_ELBOW': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_WRIST': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_HIP': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_KNEE': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_ANKLE': {'mediapipe': 0.3, 'rcnn': 0.7}}
# LEFT_SHOULDER - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.96, R-CNN Consistency: 0.98
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.94, R-CNN Consistency: 0.97
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_HIP: Using R-CNN prediction.
# LEFT_KNEE - MediaPipe Consistency: 0.96, R-CNN Consistency: 0.99
# LEFT_KNEE: Using R-CNN prediction.
# LEFT_ANKLE - MediaPipe Consistency: 0.98, R-CNN Consistency: 0.99
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.54916, y=0.22157, confidence=1.00)
# LEFT_ELBOW: (x=0.49974, y=0.34675, confidence=1.00)
# LEFT_WRIST: (x=0.43748, y=0.41511, confidence=1.00)
# LEFT_HIP: (x=0.59938, y=0.42579, confidence=1.00)
# LEFT_KNEE: (x=0.51019, y=0.55259, confidence=1.00)
# LEFT_ANKLE: (x=0.53192, y=0.76481, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\CHECK DATASET\checkdataset_output_2video\109.png
#
# Processing 11.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.48521, y=0.28955, confidence=1.00)
# LEFT_ELBOW: (x=0.46144, y=0.39149, confidence=0.97)
# LEFT_WRIST: (x=0.41090, y=0.37203, confidence=0.97)
# LEFT_HIP: (x=0.55694, y=0.39082, confidence=1.00)
# LEFT_KNEE: (x=0.47237, y=0.44428, confidence=0.95)
# LEFT_ANKLE: (x=0.54395, y=0.52193, confidence=0.93)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.48417, y=0.28171, confidence=1.00)
# LEFT_ELBOW: (x=0.46167, y=0.39368, confidence=1.00)
# LEFT_WRIST: (x=0.40543, y=0.36302, confidence=1.00)
# LEFT_HIP: (x=0.55467, y=0.37635, confidence=1.00)
# LEFT_KNEE: (x=0.47667, y=0.44833, confidence=1.00)
# LEFT_ANKLE: (x=0.55317, y=0.52164, confidence=1.00)
# Pose classified as cycling. Using weights: {'LEFT_SHOULDER': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_ELBOW': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_WRIST': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_HIP': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_KNEE': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_ANKLE': {'mediapipe': 0.3, 'rcnn': 0.7}}
# LEFT_SHOULDER - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.96, R-CNN Consistency: 0.98
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.95, R-CNN Consistency: 0.97
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 0.98, R-CNN Consistency: 0.98
# LEFT_HIP: Using R-CNN prediction.
# LEFT_KNEE - MediaPipe Consistency: 0.94, R-CNN Consistency: 0.97
# LEFT_KNEE: Using R-CNN prediction.
# LEFT_ANKLE - MediaPipe Consistency: 0.94, R-CNN Consistency: 0.99
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.48417, y=0.28171, confidence=1.00)
# LEFT_ELBOW: (x=0.46156, y=0.39258, confidence=1.00)
# LEFT_WRIST: (x=0.40543, y=0.36302, confidence=1.00)
# LEFT_HIP: (x=0.55467, y=0.37635, confidence=1.00)
# LEFT_KNEE: (x=0.47667, y=0.44833, confidence=1.00)
# LEFT_ANKLE: (x=0.55317, y=0.52164, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\CHECK DATASET\checkdataset_output_2video\11.png
#
# Processing 110.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.54000, y=0.24389, confidence=1.00)
# LEFT_ELBOW: (x=0.49793, y=0.35582, confidence=0.99)
# LEFT_WRIST: (x=0.43981, y=0.41070, confidence=0.98)
# LEFT_HIP: (x=0.59797, y=0.43666, confidence=1.00)
# LEFT_KNEE: (x=0.52120, y=0.57972, confidence=0.97)
# LEFT_ANKLE: (x=0.54451, y=0.76439, confidence=0.99)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.54820, y=0.22246, confidence=1.00)
# LEFT_ELBOW: (x=0.49948, y=0.33727, confidence=1.00)
# LEFT_WRIST: (x=0.43651, y=0.41604, confidence=1.00)
# LEFT_HIP: (x=0.59542, y=0.42672, confidence=1.00)
# LEFT_KNEE: (x=0.51896, y=0.57624, confidence=1.00)
# LEFT_ANKLE: (x=0.54745, y=0.77516, confidence=1.00)
# Pose classified as cycling. Using weights: {'LEFT_SHOULDER': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_ELBOW': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_WRIST': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_HIP': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_KNEE': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_ANKLE': {'mediapipe': 0.3, 'rcnn': 0.7}}
# LEFT_SHOULDER - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.97, R-CNN Consistency: 0.98
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.96, R-CNN Consistency: 0.97
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_HIP: Using R-CNN prediction.
# LEFT_KNEE - MediaPipe Consistency: 0.98, R-CNN Consistency: 1.00
# LEFT_KNEE: Using R-CNN prediction.
# LEFT_ANKLE - MediaPipe Consistency: 0.99, R-CNN Consistency: 1.00
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.54820, y=0.22246, confidence=1.00)
# LEFT_ELBOW: (x=0.49870, y=0.34655, confidence=1.00)
# LEFT_WRIST: (x=0.43651, y=0.41604, confidence=1.00)
# LEFT_HIP: (x=0.59542, y=0.42672, confidence=1.00)
# LEFT_KNEE: (x=0.51896, y=0.57624, confidence=1.00)
# LEFT_ANKLE: (x=0.54745, y=0.77516, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\CHECK DATASET\checkdataset_output_2video\110.png
#
# Processing 111.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.53776, y=0.24260, confidence=1.00)
# LEFT_ELBOW: (x=0.49771, y=0.35416, confidence=0.99)
# LEFT_WRIST: (x=0.43945, y=0.41011, confidence=0.98)
# LEFT_HIP: (x=0.59841, y=0.44029, confidence=1.00)
# LEFT_KNEE: (x=0.52543, y=0.58192, confidence=0.99)
# LEFT_ANKLE: (x=0.55833, y=0.76362, confidence=0.99)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.54741, y=0.22421, confidence=1.00)
# LEFT_ELBOW: (x=0.49867, y=0.34428, confidence=1.00)
# LEFT_WRIST: (x=0.43793, y=0.41765, confidence=1.00)
# LEFT_HIP: (x=0.59540, y=0.42432, confidence=1.00)
# LEFT_KNEE: (x=0.52191, y=0.58040, confidence=1.00)
# LEFT_ANKLE: (x=0.56391, y=0.77384, confidence=1.00)
# Pose classified as cycling. Using weights: {'LEFT_SHOULDER': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_ELBOW': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_WRIST': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_HIP': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_KNEE': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_ANKLE': {'mediapipe': 0.3, 'rcnn': 0.7}}
# LEFT_SHOULDER - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.98, R-CNN Consistency: 0.98
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.96, R-CNN Consistency: 0.98
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_HIP: Using R-CNN prediction.
# LEFT_KNEE - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_KNEE: Using R-CNN prediction.
# LEFT_ANKLE - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.54741, y=0.22421, confidence=1.00)
# LEFT_ELBOW: (x=0.49819, y=0.34922, confidence=1.00)
# LEFT_WRIST: (x=0.43793, y=0.41765, confidence=1.00)
# LEFT_HIP: (x=0.59540, y=0.42432, confidence=1.00)
# LEFT_KNEE: (x=0.52191, y=0.58040, confidence=1.00)
# LEFT_ANKLE: (x=0.56391, y=0.77384, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\CHECK DATASET\checkdataset_output_2video\111.png
#
# Processing 112.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.53971, y=0.23929, confidence=1.00)
# LEFT_ELBOW: (x=0.50280, y=0.35243, confidence=0.99)
# LEFT_WRIST: (x=0.44522, y=0.40371, confidence=0.97)
# LEFT_HIP: (x=0.59955, y=0.43690, confidence=1.00)
# LEFT_KNEE: (x=0.52690, y=0.57381, confidence=0.99)
# LEFT_ANKLE: (x=0.57086, y=0.74887, confidence=0.99)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.54805, y=0.22420, confidence=1.00)
# LEFT_ELBOW: (x=0.49790, y=0.34034, confidence=1.00)
# LEFT_WRIST: (x=0.43727, y=0.41643, confidence=1.00)
# LEFT_HIP: (x=0.59296, y=0.42711, confidence=1.00)
# LEFT_KNEE: (x=0.52035, y=0.56995, confidence=1.00)
# LEFT_ANKLE: (x=0.57574, y=0.75417, confidence=1.00)
# Pose classified as cycling. Using weights: {'LEFT_SHOULDER': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_ELBOW': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_WRIST': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_HIP': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_KNEE': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_ANKLE': {'mediapipe': 0.3, 'rcnn': 0.7}}
# LEFT_SHOULDER - MediaPipe Consistency: 0.98, R-CNN Consistency: 0.98
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.96, R-CNN Consistency: 0.97
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.95, R-CNN Consistency: 0.96
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_HIP: Using R-CNN prediction.
# LEFT_KNEE - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_KNEE: Using R-CNN prediction.
# LEFT_ANKLE - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.54805, y=0.22420, confidence=1.00)
# LEFT_ELBOW: (x=0.50035, y=0.34638, confidence=1.00)
# LEFT_WRIST: (x=0.43727, y=0.41643, confidence=1.00)
# LEFT_HIP: (x=0.59296, y=0.42711, confidence=1.00)
# LEFT_KNEE: (x=0.52035, y=0.56995, confidence=1.00)
# LEFT_ANKLE: (x=0.57574, y=0.75417, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\CHECK DATASET\checkdataset_output_2video\112.png
#
# Processing 113.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.54064, y=0.23933, confidence=1.00)
# LEFT_ELBOW: (x=0.50391, y=0.35157, confidence=0.99)
# LEFT_WRIST: (x=0.44590, y=0.40608, confidence=0.97)
# LEFT_HIP: (x=0.59678, y=0.43012, confidence=1.00)
# LEFT_KNEE: (x=0.51600, y=0.55533, confidence=0.99)
# LEFT_ANKLE: (x=0.56937, y=0.70986, confidence=0.98)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.54942, y=0.22118, confidence=1.00)
# LEFT_ELBOW: (x=0.49928, y=0.33862, confidence=1.00)
# LEFT_WRIST: (x=0.43642, y=0.41602, confidence=1.00)
# LEFT_HIP: (x=0.59731, y=0.42003, confidence=1.00)
# LEFT_KNEE: (x=0.51649, y=0.55882, confidence=1.00)
# LEFT_ANKLE: (x=0.58534, y=0.72296, confidence=1.00)
# Pose classified as cycling. Using weights: {'LEFT_SHOULDER': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_ELBOW': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_WRIST': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_HIP': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_KNEE': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_ANKLE': {'mediapipe': 0.3, 'rcnn': 0.7}}
# LEFT_SHOULDER - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.97, R-CNN Consistency: 0.98
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.95, R-CNN Consistency: 0.97
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_HIP: Using R-CNN prediction.
# LEFT_KNEE - MediaPipe Consistency: 0.98, R-CNN Consistency: 0.99
# LEFT_KNEE: Using R-CNN prediction.
# LEFT_ANKLE - MediaPipe Consistency: 0.97, R-CNN Consistency: 0.99
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.54942, y=0.22118, confidence=1.00)
# LEFT_ELBOW: (x=0.50160, y=0.34509, confidence=1.00)
# LEFT_WRIST: (x=0.43642, y=0.41602, confidence=1.00)
# LEFT_HIP: (x=0.59731, y=0.42003, confidence=1.00)
# LEFT_KNEE: (x=0.51649, y=0.55882, confidence=1.00)
# LEFT_ANKLE: (x=0.58534, y=0.72296, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\CHECK DATASET\checkdataset_output_2video\113.png
#
# Processing 114.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.54019, y=0.23687, confidence=1.00)
# LEFT_ELBOW: (x=0.49947, y=0.35313, confidence=0.99)
# LEFT_WRIST: (x=0.44099, y=0.40956, confidence=0.98)
# LEFT_HIP: (x=0.58952, y=0.42270, confidence=1.00)
# LEFT_KNEE: (x=0.50550, y=0.53789, confidence=0.99)
# LEFT_ANKLE: (x=0.57135, y=0.67596, confidence=0.98)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.54850, y=0.22563, confidence=1.00)
# LEFT_ELBOW: (x=0.49757, y=0.34441, confidence=1.00)
# LEFT_WRIST: (x=0.43541, y=0.41381, confidence=1.00)
# LEFT_HIP: (x=0.59568, y=0.41515, confidence=1.00)
# LEFT_KNEE: (x=0.51030, y=0.54594, confidence=1.00)
# LEFT_ANKLE: (x=0.58744, y=0.69275, confidence=1.00)
# Pose classified as cycling. Using weights: {'LEFT_SHOULDER': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_ELBOW': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_WRIST': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_HIP': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_KNEE': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_ANKLE': {'mediapipe': 0.3, 'rcnn': 0.7}}
# LEFT_SHOULDER - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.98, R-CNN Consistency: 0.99
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.97, R-CNN Consistency: 0.98
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_HIP: Using R-CNN prediction.
# LEFT_KNEE - MediaPipe Consistency: 0.98, R-CNN Consistency: 0.99
# LEFT_KNEE: Using R-CNN prediction.
# LEFT_ANKLE - MediaPipe Consistency: 0.98, R-CNN Consistency: 0.99
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.54850, y=0.22563, confidence=1.00)
# LEFT_ELBOW: (x=0.49852, y=0.34877, confidence=1.00)
# LEFT_WRIST: (x=0.43541, y=0.41381, confidence=1.00)
# LEFT_HIP: (x=0.59568, y=0.41515, confidence=1.00)
# LEFT_KNEE: (x=0.51030, y=0.54594, confidence=1.00)
# LEFT_ANKLE: (x=0.58744, y=0.69275, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\CHECK DATASET\checkdataset_output_2video\114.png
#
# Processing 115.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.54134, y=0.23737, confidence=1.00)
# LEFT_ELBOW: (x=0.50175, y=0.35509, confidence=0.99)
# LEFT_WRIST: (x=0.43941, y=0.41027, confidence=0.98)
# LEFT_HIP: (x=0.59171, y=0.41881, confidence=1.00)
# LEFT_KNEE: (x=0.50665, y=0.53232, confidence=0.98)
# LEFT_ANKLE: (x=0.57714, y=0.65492, confidence=0.98)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.54880, y=0.22641, confidence=1.00)
# LEFT_ELBOW: (x=0.49636, y=0.34247, confidence=1.00)
# LEFT_WRIST: (x=0.43569, y=0.41317, confidence=1.00)
# LEFT_HIP: (x=0.59449, y=0.42384, confidence=1.00)
# LEFT_KNEE: (x=0.50460, y=0.52922, confidence=1.00)
# LEFT_ANKLE: (x=0.58550, y=0.65328, confidence=1.00)
# Pose classified as cycling. Using weights: {'LEFT_SHOULDER': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_ELBOW': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_WRIST': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_HIP': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_KNEE': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_ANKLE': {'mediapipe': 0.3, 'rcnn': 0.7}}
# LEFT_SHOULDER - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.97, R-CNN Consistency: 0.98
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.96, R-CNN Consistency: 0.97
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_HIP: Using R-CNN prediction.
# LEFT_KNEE - MediaPipe Consistency: 0.98, R-CNN Consistency: 0.99
# LEFT_KNEE: Using R-CNN prediction.
# LEFT_ANKLE - MediaPipe Consistency: 0.97, R-CNN Consistency: 0.99
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.54880, y=0.22641, confidence=1.00)
# LEFT_ELBOW: (x=0.49906, y=0.34878, confidence=1.00)
# LEFT_WRIST: (x=0.43569, y=0.41317, confidence=1.00)
# LEFT_HIP: (x=0.59449, y=0.42384, confidence=1.00)
# LEFT_KNEE: (x=0.50460, y=0.52922, confidence=1.00)
# LEFT_ANKLE: (x=0.58550, y=0.65328, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\CHECK DATASET\checkdataset_output_2video\115.png
#
# Processing 116.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.54283, y=0.23655, confidence=1.00)
# LEFT_ELBOW: (x=0.50343, y=0.35244, confidence=0.99)
# LEFT_WRIST: (x=0.44170, y=0.41058, confidence=0.98)
# LEFT_HIP: (x=0.59151, y=0.41567, confidence=1.00)
# LEFT_KNEE: (x=0.49902, y=0.49960, confidence=0.98)
# LEFT_ANKLE: (x=0.56375, y=0.60768, confidence=0.95)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.54995, y=0.22477, confidence=1.00)
# LEFT_ELBOW: (x=0.49833, y=0.33692, confidence=1.00)
# LEFT_WRIST: (x=0.43473, y=0.41301, confidence=1.00)
# LEFT_HIP: (x=0.59635, y=0.42236, confidence=1.00)
# LEFT_KNEE: (x=0.49907, y=0.50380, confidence=1.00)
# LEFT_ANKLE: (x=0.58063, y=0.62796, confidence=1.00)
# Pose classified as cycling. Using weights: {'LEFT_SHOULDER': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_ELBOW': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_WRIST': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_HIP': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_KNEE': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_ANKLE': {'mediapipe': 0.3, 'rcnn': 0.7}}
# LEFT_SHOULDER - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.97, R-CNN Consistency: 0.98
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.96, R-CNN Consistency: 0.97
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_HIP: Using R-CNN prediction.
# LEFT_KNEE - MediaPipe Consistency: 0.98, R-CNN Consistency: 0.99
# LEFT_KNEE: Using R-CNN prediction.
# LEFT_ANKLE - MediaPipe Consistency: 0.95, R-CNN Consistency: 0.99
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.54995, y=0.22477, confidence=1.00)
# LEFT_ELBOW: (x=0.50088, y=0.34468, confidence=1.00)
# LEFT_WRIST: (x=0.43473, y=0.41301, confidence=1.00)
# LEFT_HIP: (x=0.59635, y=0.42236, confidence=1.00)
# LEFT_KNEE: (x=0.49907, y=0.50380, confidence=1.00)
# LEFT_ANKLE: (x=0.58063, y=0.62796, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\CHECK DATASET\checkdataset_output_2video\116.png
#
# Processing 117.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.54257, y=0.23439, confidence=1.00)
# LEFT_ELBOW: (x=0.50956, y=0.33870, confidence=0.98)
# LEFT_WRIST: (x=0.44552, y=0.40251, confidence=0.98)
# LEFT_HIP: (x=0.59136, y=0.42115, confidence=1.00)
# LEFT_KNEE: (x=0.48171, y=0.47192, confidence=0.97)
# LEFT_ANKLE: (x=0.55181, y=0.57939, confidence=0.95)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.54867, y=0.22476, confidence=1.00)
# LEFT_ELBOW: (x=0.49706, y=0.34358, confidence=1.00)
# LEFT_WRIST: (x=0.43423, y=0.41968, confidence=1.00)
# LEFT_HIP: (x=0.59430, y=0.42235, confidence=1.00)
# LEFT_KNEE: (x=0.49407, y=0.47709, confidence=1.00)
# LEFT_ANKLE: (x=0.57111, y=0.60793, confidence=1.00)
# Pose classified as cycling. Using weights: {'LEFT_SHOULDER': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_ELBOW': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_WRIST': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_HIP': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_KNEE': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_ANKLE': {'mediapipe': 0.3, 'rcnn': 0.7}}
# LEFT_SHOULDER - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.97, R-CNN Consistency: 0.98
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.97, R-CNN Consistency: 0.98
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_HIP: Using R-CNN prediction.
# LEFT_KNEE - MediaPipe Consistency: 0.97, R-CNN Consistency: 0.99
# LEFT_KNEE: Using R-CNN prediction.
# LEFT_ANKLE - MediaPipe Consistency: 0.96, R-CNN Consistency: 0.99
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.54867, y=0.22476, confidence=1.00)
# LEFT_ELBOW: (x=0.50331, y=0.34114, confidence=1.00)
# LEFT_WRIST: (x=0.43423, y=0.41968, confidence=1.00)
# LEFT_HIP: (x=0.59430, y=0.42235, confidence=1.00)
# LEFT_KNEE: (x=0.49407, y=0.47709, confidence=1.00)
# LEFT_ANKLE: (x=0.57111, y=0.60793, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\CHECK DATASET\checkdataset_output_2video\117.png
#
# Processing 118.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.54065, y=0.23276, confidence=1.00)
# LEFT_ELBOW: (x=0.50319, y=0.34421, confidence=0.98)
# LEFT_WRIST: (x=0.44080, y=0.40616, confidence=0.98)
# LEFT_HIP: (x=0.59246, y=0.41583, confidence=1.00)
# LEFT_KNEE: (x=0.48691, y=0.45913, confidence=0.97)
# LEFT_ANKLE: (x=0.54549, y=0.58973, confidence=0.96)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.54930, y=0.22077, confidence=1.00)
# LEFT_ELBOW: (x=0.49764, y=0.33938, confidence=1.00)
# LEFT_WRIST: (x=0.43473, y=0.41534, confidence=1.00)
# LEFT_HIP: (x=0.59274, y=0.41934, confidence=1.00)
# LEFT_KNEE: (x=0.48940, y=0.46065, confidence=1.00)
# LEFT_ANKLE: (x=0.55455, y=0.59926, confidence=1.00)
# Pose classified as cycling. Using weights: {'LEFT_SHOULDER': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_ELBOW': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_WRIST': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_HIP': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_KNEE': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_ANKLE': {'mediapipe': 0.3, 'rcnn': 0.7}}
# LEFT_SHOULDER - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.97, R-CNN Consistency: 0.98
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.97, R-CNN Consistency: 0.98
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_HIP: Using R-CNN prediction.
# LEFT_KNEE - MediaPipe Consistency: 0.98, R-CNN Consistency: 1.00
# LEFT_KNEE: Using R-CNN prediction.
# LEFT_ANKLE - MediaPipe Consistency: 0.97, R-CNN Consistency: 1.00
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.54930, y=0.22077, confidence=1.00)
# LEFT_ELBOW: (x=0.50041, y=0.34180, confidence=1.00)
# LEFT_WRIST: (x=0.43473, y=0.41534, confidence=1.00)
# LEFT_HIP: (x=0.59274, y=0.41934, confidence=1.00)
# LEFT_KNEE: (x=0.48940, y=0.46065, confidence=1.00)
# LEFT_ANKLE: (x=0.55455, y=0.59926, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\CHECK DATASET\checkdataset_output_2video\118.png
#
# Processing 119.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.53844, y=0.23433, confidence=1.00)
# LEFT_ELBOW: (x=0.50332, y=0.34344, confidence=0.95)
# LEFT_WRIST: (x=0.43991, y=0.41240, confidence=0.96)
# LEFT_HIP: (x=0.59063, y=0.40482, confidence=1.00)
# LEFT_KNEE: (x=0.48779, y=0.46135, confidence=0.96)
# LEFT_ANKLE: (x=0.53819, y=0.61562, confidence=0.95)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.54676, y=0.22236, confidence=1.00)
# LEFT_ELBOW: (x=0.49729, y=0.34101, confidence=1.00)
# LEFT_WRIST: (x=0.43657, y=0.41700, confidence=1.00)
# LEFT_HIP: (x=0.59549, y=0.41033, confidence=1.00)
# LEFT_KNEE: (x=0.48829, y=0.45566, confidence=1.00)
# LEFT_ANKLE: (x=0.53927, y=0.63430, confidence=1.00)
# ...
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.95, R-CNN Consistency: 0.98
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.94, R-CNN Consistency: 0.97
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 0.97, R-CNN Consistency: 0.98
# LEFT_HIP: Using R-CNN prediction.
# LEFT_KNEE - MediaPipe Consistency: 0.95, R-CNN Consistency: 0.98
# LEFT_KNEE: Using R-CNN prediction.
# LEFT_ANKLE - MediaPipe Consistency: 0.95, R-CNN Consistency: 1.00
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.54844, y=0.22307, confidence=1.00)
# LEFT_ELBOW: (x=0.50064, y=0.34158, confidence=1.00)
# LEFT_WRIST: (x=0.43901, y=0.42332, confidence=1.00)
# LEFT_HIP: (x=0.59491, y=0.41397, confidence=1.00)
# LEFT_KNEE: (x=0.49223, y=0.45936, confidence=1.00)
# LEFT_ANKLE: (x=0.53870, y=0.64225, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\CHECK DATASET\checkdataset_output_2video\92.png
#
# Processing 93.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.54143, y=0.23206, confidence=1.00)
# LEFT_ELBOW: (x=0.50818, y=0.34547, confidence=0.96)
# LEFT_WRIST: (x=0.44380, y=0.40505, confidence=0.96)
# LEFT_HIP: (x=0.59238, y=0.41119, confidence=1.00)
# LEFT_KNEE: (x=0.49655, y=0.48211, confidence=0.93)
# LEFT_ANKLE: (x=0.52970, y=0.68092, confidence=0.90)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.54957, y=0.22146, confidence=1.00)
# LEFT_ELBOW: (x=0.49864, y=0.34026, confidence=1.00)
# LEFT_WRIST: (x=0.43798, y=0.41635, confidence=1.00)
# LEFT_HIP: (x=0.59900, y=0.41768, confidence=1.00)
# LEFT_KNEE: (x=0.49640, y=0.48842, confidence=1.00)
# LEFT_ANKLE: (x=0.52186, y=0.67930, confidence=1.00)
# Pose classified as cycling. Using weights: {'LEFT_SHOULDER': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_ELBOW': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_WRIST': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_HIP': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_KNEE': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_ANKLE': {'mediapipe': 0.3, 'rcnn': 0.7}}
# LEFT_SHOULDER - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.94, R-CNN Consistency: 0.97
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.94, R-CNN Consistency: 0.97
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_HIP: Using R-CNN prediction.
# LEFT_KNEE - MediaPipe Consistency: 0.95, R-CNN Consistency: 0.99
# LEFT_KNEE: Using R-CNN prediction.
# LEFT_ANKLE - MediaPipe Consistency: 0.93, R-CNN Consistency: 0.99
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.54957, y=0.22146, confidence=1.00)
# LEFT_ELBOW: (x=0.50341, y=0.34286, confidence=1.00)
# LEFT_WRIST: (x=0.43798, y=0.41635, confidence=1.00)
# LEFT_HIP: (x=0.59900, y=0.41768, confidence=1.00)
# LEFT_KNEE: (x=0.49640, y=0.48842, confidence=1.00)
# LEFT_ANKLE: (x=0.52186, y=0.67930, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\CHECK DATASET\checkdataset_output_2video\93.png
#
# Processing 94.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.54086, y=0.23604, confidence=1.00)
# LEFT_ELBOW: (x=0.50371, y=0.35561, confidence=0.98)
# LEFT_WRIST: (x=0.44164, y=0.41118, confidence=0.97)
# LEFT_HIP: (x=0.59505, y=0.42111, confidence=1.00)
# LEFT_KNEE: (x=0.50729, y=0.52250, confidence=0.95)
# LEFT_ANKLE: (x=0.52905, y=0.71026, confidence=0.95)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.54959, y=0.22378, confidence=1.00)
# LEFT_ELBOW: (x=0.49638, y=0.34258, confidence=1.00)
# LEFT_WRIST: (x=0.43641, y=0.41333, confidence=1.00)
# LEFT_HIP: (x=0.60431, y=0.42267, confidence=1.00)
# LEFT_KNEE: (x=0.50162, y=0.52012, confidence=1.00)
# LEFT_ANKLE: (x=0.52636, y=0.73637, confidence=1.00)
# Pose classified as cycling. Using weights: {'LEFT_SHOULDER': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_ELBOW': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_WRIST': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_HIP': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_KNEE': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_ANKLE': {'mediapipe': 0.3, 'rcnn': 0.7}}
# LEFT_SHOULDER - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.96, R-CNN Consistency: 0.97
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.95, R-CNN Consistency: 0.97
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_HIP: Using R-CNN prediction.
# LEFT_KNEE - MediaPipe Consistency: 0.96, R-CNN Consistency: 0.99
# LEFT_KNEE: Using R-CNN prediction.
# LEFT_ANKLE - MediaPipe Consistency: 0.96, R-CNN Consistency: 1.00
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.54959, y=0.22378, confidence=1.00)
# LEFT_ELBOW: (x=0.50004, y=0.34910, confidence=1.00)
# LEFT_WRIST: (x=0.43641, y=0.41333, confidence=1.00)
# LEFT_HIP: (x=0.60431, y=0.42267, confidence=1.00)
# LEFT_KNEE: (x=0.50162, y=0.52012, confidence=1.00)
# LEFT_ANKLE: (x=0.52636, y=0.73637, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\CHECK DATASET\checkdataset_output_2video\94.png
#
# Processing 95.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.54110, y=0.23675, confidence=1.00)
# LEFT_ELBOW: (x=0.50393, y=0.35112, confidence=0.98)
# LEFT_WRIST: (x=0.44225, y=0.40780, confidence=0.98)
# LEFT_HIP: (x=0.59526, y=0.42917, confidence=1.00)
# LEFT_KNEE: (x=0.51575, y=0.54291, confidence=0.96)
# LEFT_ANKLE: (x=0.53684, y=0.73123, confidence=0.98)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.55032, y=0.21984, confidence=1.00)
# LEFT_ELBOW: (x=0.49722, y=0.33596, confidence=1.00)
# LEFT_WRIST: (x=0.43589, y=0.41471, confidence=1.00)
# LEFT_HIP: (x=0.59968, y=0.42539, confidence=1.00)
# LEFT_KNEE: (x=0.50918, y=0.54284, confidence=1.00)
# LEFT_ANKLE: (x=0.53087, y=0.76174, confidence=1.00)
# Pose classified as cycling. Using weights: {'LEFT_SHOULDER': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_ELBOW': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_WRIST': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_HIP': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_KNEE': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_ANKLE': {'mediapipe': 0.3, 'rcnn': 0.7}}
# LEFT_SHOULDER - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.96, R-CNN Consistency: 0.97
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.95, R-CNN Consistency: 0.96
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_HIP: Using R-CNN prediction.
# LEFT_KNEE - MediaPipe Consistency: 0.97, R-CNN Consistency: 0.99
# LEFT_KNEE: Using R-CNN prediction.
# LEFT_ANKLE - MediaPipe Consistency: 0.98, R-CNN Consistency: 1.00
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.55032, y=0.21984, confidence=1.00)
# LEFT_ELBOW: (x=0.50057, y=0.34354, confidence=1.00)
# LEFT_WRIST: (x=0.43589, y=0.41471, confidence=1.00)
# LEFT_HIP: (x=0.59968, y=0.42539, confidence=1.00)
# LEFT_KNEE: (x=0.50918, y=0.54284, confidence=1.00)
# LEFT_ANKLE: (x=0.53087, y=0.76174, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\CHECK DATASET\checkdataset_output_2video\95.png
#
# Processing 96.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.54140, y=0.23767, confidence=1.00)
# LEFT_ELBOW: (x=0.50202, y=0.34686, confidence=0.99)
# LEFT_WRIST: (x=0.44266, y=0.40419, confidence=0.98)
# LEFT_HIP: (x=0.59536, y=0.42923, confidence=1.00)
# LEFT_KNEE: (x=0.51831, y=0.57041, confidence=0.96)
# LEFT_ANKLE: (x=0.54170, y=0.75525, confidence=0.98)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.54974, y=0.22061, confidence=1.00)
# LEFT_ELBOW: (x=0.49506, y=0.33674, confidence=1.00)
# LEFT_WRIST: (x=0.43514, y=0.41550, confidence=1.00)
# LEFT_HIP: (x=0.59468, y=0.42885, confidence=1.00)
# LEFT_KNEE: (x=0.51678, y=0.57168, confidence=1.00)
# LEFT_ANKLE: (x=0.54599, y=0.77858, confidence=1.00)
# Pose classified as cycling. Using weights: {'LEFT_SHOULDER': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_ELBOW': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_WRIST': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_HIP': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_KNEE': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_ANKLE': {'mediapipe': 0.3, 'rcnn': 0.7}}
# LEFT_SHOULDER - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.97, R-CNN Consistency: 0.97
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.95, R-CNN Consistency: 0.97
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_HIP: Using R-CNN prediction.
# LEFT_KNEE - MediaPipe Consistency: 0.97, R-CNN Consistency: 1.00
# LEFT_KNEE: Using R-CNN prediction.
# LEFT_ANKLE - MediaPipe Consistency: 0.98, R-CNN Consistency: 1.00
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.54974, y=0.22061, confidence=1.00)
# LEFT_ELBOW: (x=0.49854, y=0.34180, confidence=1.00)
# LEFT_WRIST: (x=0.43514, y=0.41550, confidence=1.00)
# LEFT_HIP: (x=0.59468, y=0.42885, confidence=1.00)
# LEFT_KNEE: (x=0.51678, y=0.57168, confidence=1.00)
# LEFT_ANKLE: (x=0.54599, y=0.77858, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\CHECK DATASET\checkdataset_output_2video\96.png
#
# Processing 97.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.53994, y=0.23924, confidence=1.00)
# LEFT_ELBOW: (x=0.50188, y=0.34958, confidence=0.99)
# LEFT_WRIST: (x=0.44596, y=0.40277, confidence=0.98)
# LEFT_HIP: (x=0.59765, y=0.43723, confidence=1.00)
# LEFT_KNEE: (x=0.52319, y=0.58333, confidence=0.98)
# LEFT_ANKLE: (x=0.55653, y=0.76348, confidence=0.99)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.54921, y=0.22405, confidence=1.00)
# LEFT_ELBOW: (x=0.49754, y=0.34286, confidence=1.00)
# LEFT_WRIST: (x=0.43763, y=0.41494, confidence=1.00)
# LEFT_HIP: (x=0.59414, y=0.42562, confidence=1.00)
# LEFT_KNEE: (x=0.52300, y=0.58181, confidence=1.00)
# LEFT_ANKLE: (x=0.55894, y=0.77003, confidence=1.00)
# Pose classified as cycling. Using weights: {'LEFT_SHOULDER': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_ELBOW': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_WRIST': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_HIP': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_KNEE': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_ANKLE': {'mediapipe': 0.3, 'rcnn': 0.7}}
# LEFT_SHOULDER - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.97, R-CNN Consistency: 0.98
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.96, R-CNN Consistency: 0.98
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_HIP: Using R-CNN prediction.
# LEFT_KNEE - MediaPipe Consistency: 0.98, R-CNN Consistency: 1.00
# LEFT_KNEE: Using R-CNN prediction.
# LEFT_ANKLE - MediaPipe Consistency: 0.99, R-CNN Consistency: 1.00
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.54921, y=0.22405, confidence=1.00)
# LEFT_ELBOW: (x=0.49971, y=0.34622, confidence=1.00)
# LEFT_WRIST: (x=0.43763, y=0.41494, confidence=1.00)
# LEFT_HIP: (x=0.59414, y=0.42562, confidence=1.00)
# LEFT_KNEE: (x=0.52300, y=0.58181, confidence=1.00)
# LEFT_ANKLE: (x=0.55894, y=0.77003, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\CHECK DATASET\checkdataset_output_2video\97.png
#
# Processing 98.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.53999, y=0.24329, confidence=1.00)
# LEFT_ELBOW: (x=0.50050, y=0.35372, confidence=0.99)
# LEFT_WRIST: (x=0.44423, y=0.40792, confidence=0.97)
# LEFT_HIP: (x=0.59817, y=0.43799, confidence=1.00)
# LEFT_KNEE: (x=0.52563, y=0.57596, confidence=1.00)
# LEFT_ANKLE: (x=0.56516, y=0.74934, confidence=0.99)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.54879, y=0.22299, confidence=1.00)
# LEFT_ELBOW: (x=0.49716, y=0.33915, confidence=1.00)
# LEFT_WRIST: (x=0.44030, y=0.41658, confidence=1.00)
# LEFT_HIP: (x=0.59218, y=0.42860, confidence=1.00)
# LEFT_KNEE: (x=0.51961, y=0.57145, confidence=1.00)
# LEFT_ANKLE: (x=0.57123, y=0.75303, confidence=1.00)
# Pose classified as cycling. Using weights: {'LEFT_SHOULDER': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_ELBOW': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_WRIST': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_HIP': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_KNEE': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_ANKLE': {'mediapipe': 0.3, 'rcnn': 0.7}}
# LEFT_SHOULDER - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.97, R-CNN Consistency: 0.97
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.95, R-CNN Consistency: 0.96
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_HIP: Using R-CNN prediction.
# LEFT_KNEE - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_KNEE: Using R-CNN prediction.
# LEFT_ANKLE - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.54879, y=0.22299, confidence=1.00)
# LEFT_ELBOW: (x=0.49883, y=0.34643, confidence=1.00)
# LEFT_WRIST: (x=0.44030, y=0.41658, confidence=1.00)
# LEFT_HIP: (x=0.59218, y=0.42860, confidence=1.00)
# LEFT_KNEE: (x=0.51961, y=0.57145, confidence=1.00)
# LEFT_ANKLE: (x=0.57123, y=0.75303, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\CHECK DATASET\checkdataset_output_2video\98.png
#
# Processing 99.png...
#
# MediaPipe Keypoints:
# LEFT_SHOULDER: (x=0.54126, y=0.23473, confidence=1.00)
# LEFT_ELBOW: (x=0.50615, y=0.34343, confidence=0.99)
# LEFT_WRIST: (x=0.44426, y=0.40684, confidence=0.98)
# LEFT_HIP: (x=0.59385, y=0.42484, confidence=1.00)
# LEFT_KNEE: (x=0.51228, y=0.55050, confidence=1.00)
# LEFT_ANKLE: (x=0.56885, y=0.71373, confidence=0.99)
#
# R-CNN Keypoints:
# LEFT_SHOULDER: (x=0.54901, y=0.22445, confidence=1.00)
# LEFT_ELBOW: (x=0.49880, y=0.34591, confidence=1.00)
# LEFT_WRIST: (x=0.43736, y=0.41665, confidence=1.00)
# LEFT_HIP: (x=0.59547, y=0.41799, confidence=1.00)
# LEFT_KNEE: (x=0.51604, y=0.56213, confidence=1.00)
# LEFT_ANKLE: (x=0.58198, y=0.73031, confidence=1.00)
# Pose classified as cycling. Using weights: {'LEFT_SHOULDER': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_ELBOW': {'mediapipe': 0.5, 'rcnn': 0.5}, 'LEFT_WRIST': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_HIP': {'mediapipe': 0.4, 'rcnn': 0.6}, 'LEFT_KNEE': {'mediapipe': 0.3, 'rcnn': 0.7}, 'LEFT_ANKLE': {'mediapipe': 0.3, 'rcnn': 0.7}}
# LEFT_SHOULDER - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_SHOULDER: Using R-CNN prediction.
# LEFT_ELBOW - MediaPipe Consistency: 0.98, R-CNN Consistency: 0.99
# LEFT_ELBOW: Using weighted averaging with weights (MP: 0.50, R-CNN: 0.50).
# LEFT_WRIST - MediaPipe Consistency: 0.97, R-CNN Consistency: 0.99
# LEFT_WRIST: Using R-CNN prediction.
# LEFT_HIP - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_HIP: Using R-CNN prediction.
# LEFT_KNEE - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_KNEE: Using R-CNN prediction.
# LEFT_ANKLE - MediaPipe Consistency: 0.99, R-CNN Consistency: 0.99
# LEFT_ANKLE: Using R-CNN prediction.
#
# Fused Keypoints:
# LEFT_SHOULDER: (x=0.54901, y=0.22445, confidence=1.00)
# LEFT_ELBOW: (x=0.50248, y=0.34467, confidence=1.00)
# LEFT_WRIST: (x=0.43736, y=0.41665, confidence=1.00)
# LEFT_HIP: (x=0.59547, y=0.41799, confidence=1.00)
# LEFT_KNEE: (x=0.51604, y=0.56213, confidence=1.00)
# LEFT_ANKLE: (x=0.58198, y=0.73031, confidence=1.00)
# Saved annotated image to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\CHECK DATASET\checkdataset_output_2video\99.png
# Saved keypoint coordinates to C:\PJT2\Orbbec_Dataset_New\Orbbec_Dataset\Dataset\CHECK DATASET\checkdataset_2video_coordinates.xlsx
